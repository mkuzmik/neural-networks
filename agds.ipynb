# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
import pandas as pd
import copy

# %matplotlib inline

# %%
iris_dataset = sklearn.datasets.load_iris()

df = pd.DataFrame(iris_dataset['data'])
df['class'] = pd.Series(iris_dataset.target)
df.rename(columns={
    0: 'sle',
    1: 'swi',
    2: 'ple',
    3: 'pwi'
}, inplace=True)

df.head()
entities = df.to_dict(orient='records')
samples = []
for idx,params in enumerate(entities):
    samples += [{
        'id': idx,
        'params': params
    }]
    
samples
# Out:
# [{'id': 0,
#   'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 1,
#   'params': {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 2,
#   'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 3,
#   'params': {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 4,
#   'params': {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 5,
#   'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0}},
#  {'id': 6,
#   'params': {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#  {'id': 7,
#   'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 8,
#   'params': {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 9,
#   'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0}},
#  {'id': 10,
#   'params': {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 11,
#   'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 12,
#   'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#  {'id': 13,
#   'params': {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0}},
#  {'id': 14,
#   'params': {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 15,
#   'params': {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#  {'id': 16,
#   'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0}},
#  {'id': 17,
#   'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#  {'id': 18,
#   'params': {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0}},
#  {'id': 19,
#   'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0}},
#  {'id': 20,
#   'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 21,
#   'params': {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#  {'id': 22,
#   'params': {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 23,
#   'params': {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0}},
#  {'id': 24,
#   'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 25,
#   'params': {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 26,
#   'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0}},
#  {'id': 27,
#   'params': {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 28,
#   'params': {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 29,
#   'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 30,
#   'params': {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 31,
#   'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#  {'id': 32,
#   'params': {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0}},
#  {'id': 33,
#   'params': {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 34,
#   'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 35,
#   'params': {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 36,
#   'params': {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 37,
#   'params': {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#  {'id': 38,
#   'params': {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 39,
#   'params': {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 40,
#   'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0}},
#  {'id': 41,
#   'params': {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0}},
#  {'id': 42,
#   'params': {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 43,
#   'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0}},
#  {'id': 44,
#   'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0}},
#  {'id': 45,
#   'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#  {'id': 46,
#   'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 47,
#   'params': {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 48,
#   'params': {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 49,
#   'params': {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#  {'id': 50,
#   'params': {'sle': 7.0, 'swi': 3.2, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0}},
#  {'id': 51,
#   'params': {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 52,
#   'params': {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 53,
#   'params': {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 54,
#   'params': {'sle': 6.5, 'swi': 2.8, 'ple': 4.6, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 55,
#   'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 56,
#   'params': {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0}},
#  {'id': 57,
#   'params': {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0}},
#  {'id': 58,
#   'params': {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 59,
#   'params': {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0}},
#  {'id': 60,
#   'params': {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0}},
#  {'id': 61,
#   'params': {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 62,
#   'params': {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0}},
#  {'id': 63,
#   'params': {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0}},
#  {'id': 64,
#   'params': {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 65,
#   'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0}},
#  {'id': 66,
#   'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 67,
#   'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0}},
#  {'id': 68,
#   'params': {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 69,
#   'params': {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0}},
#  {'id': 70,
#   'params': {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0}},
#  {'id': 71,
#   'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 72,
#   'params': {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 73,
#   'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0}},
#  {'id': 74,
#   'params': {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 75,
#   'params': {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0}},
#  {'id': 76,
#   'params': {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0}},
#  {'id': 77,
#   'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0}},
#  {'id': 78,
#   'params': {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 79,
#   'params': {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0}},
#  {'id': 80,
#   'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0}},
#  {'id': 81,
#   'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0}},
#  {'id': 82,
#   'params': {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0}},
#  {'id': 83,
#   'params': {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0}},
#  {'id': 84,
#   'params': {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 85,
#   'params': {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0}},
#  {'id': 86,
#   'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0}},
#  {'id': 87,
#   'params': {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 88,
#   'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 89,
#   'params': {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 90,
#   'params': {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0}},
#  {'id': 91,
#   'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0}},
#  {'id': 92,
#   'params': {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0}},
#  {'id': 93,
#   'params': {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0}},
#  {'id': 94,
#   'params': {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 95,
#   'params': {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0}},
#  {'id': 96,
#   'params': {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 97,
#   'params': {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 98,
#   'params': {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0}},
#  {'id': 99,
#   'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0}},
#  {'id': 100,
#   'params': {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0}},
#  {'id': 101,
#   'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0}},
#  {'id': 102,
#   'params': {'sle': 7.1, 'swi': 3.0, 'ple': 5.9, 'pwi': 2.1, 'class': 2.0}},
#  {'id': 103,
#   'params': {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 104,
#   'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0}},
#  {'id': 105,
#   'params': {'sle': 7.6, 'swi': 3.0, 'ple': 6.6, 'pwi': 2.1, 'class': 2.0}},
#  {'id': 106,
#   'params': {'sle': 4.9, 'swi': 2.5, 'ple': 4.5, 'pwi': 1.7, 'class': 2.0}},
#  {'id': 107,
#   'params': {'sle': 7.3, 'swi': 2.9, 'ple': 6.3, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 108,
#   'params': {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 109,
#   'params': {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0}},
#  {'id': 110,
#   'params': {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0}},
#  {'id': 111,
#   'params': {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0}},
#  {'id': 112,
#   'params': {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0}},
#  {'id': 113,
#   'params': {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0}},
#  {'id': 114,
#   'params': {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0}},
#  {'id': 115,
#   'params': {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0}},
#  {'id': 116,
#   'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 117,
#   'params': {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0}},
#  {'id': 118,
#   'params': {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0}},
#  {'id': 119,
#   'params': {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0}},
#  {'id': 120,
#   'params': {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0}},
#  {'id': 121,
#   'params': {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0}},
#  {'id': 122,
#   'params': {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0}},
#  {'id': 123,
#   'params': {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 124,
#   'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0}},
#  {'id': 125,
#   'params': {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 126,
#   'params': {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 127,
#   'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 128,
#   'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0}},
#  {'id': 129,
#   'params': {'sle': 7.2, 'swi': 3.0, 'ple': 5.8, 'pwi': 1.6, 'class': 2.0}},
#  {'id': 130,
#   'params': {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0}},
#  {'id': 131,
#   'params': {'sle': 7.9, 'swi': 3.8, 'ple': 6.4, 'pwi': 2.0, 'class': 2.0}},
#  {'id': 132,
#   'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0}},
#  {'id': 133,
#   'params': {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0}},
#  {'id': 134,
#   'params': {'sle': 6.1, 'swi': 2.6, 'ple': 5.6, 'pwi': 1.4, 'class': 2.0}},
#  {'id': 135,
#   'params': {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0}},
#  {'id': 136,
#   'params': {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#  {'id': 137,
#   'params': {'sle': 6.4, 'swi': 3.1, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 138,
#   'params': {'sle': 6.0, 'swi': 3.0, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0}},
#  {'id': 139,
#   'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0}},
#  {'id': 140,
#   'params': {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#  {'id': 141,
#   'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0}},
#  {'id': 142,
#   'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0}},
#  {'id': 143,
#   'params': {'sle': 6.8, 'swi': 3.2, 'ple': 5.9, 'pwi': 2.3, 'class': 2.0}},
#  {'id': 144,
#   'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.5, 'class': 2.0}},
#  {'id': 145,
#   'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0}},
#  {'id': 146,
#   'params': {'sle': 6.3, 'swi': 2.5, 'ple': 5.0, 'pwi': 1.9, 'class': 2.0}},
#  {'id': 147,
#   'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.0, 'class': 2.0}},
#  {'id': 148,
#   'params': {'sle': 6.2, 'swi': 3.4, 'ple': 5.4, 'pwi': 2.3, 'class': 2.0}},
#  {'id': 149,
#   'params': {'sle': 5.9, 'swi': 3.0, 'ple': 5.1, 'pwi': 1.8, 'class': 2.0}}]

# %%
def build_agds(df):

    params = {}

    for param in df.columns.tolist():
        params.update({
            param: sorted(set(df[param].tolist()))
        })

    for (param, values) in params.items():
        connected_nodes = []
        for node in values:
            connected_nodes += [{
                    'value': node,
                    'samples': [sample for sample in samples if sample['params'][param] == node]
                }]
            params[param] = connected_nodes

    return params

agds = build_agds(df)
agds
# Out:
# {'sle': [{'value': 4.3,
#    'samples': [{'id': 13,
#      'params': {'sle': 4.3,
#       'swi': 3.0,
#       'ple': 1.1,
#       'pwi': 0.1,
#       'class': 0.0}}]},
#   {'value': 4.4,
#    'samples': [{'id': 8,
#      'params': {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 38,
#      'params': {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 42,
#      'params': {'sle': 4.4,
#       'swi': 3.2,
#       'ple': 1.3,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 4.5,
#    'samples': [{'id': 41,
#      'params': {'sle': 4.5,
#       'swi': 2.3,
#       'ple': 1.3,
#       'pwi': 0.3,
#       'class': 0.0}}]},
#   {'value': 4.6,
#    'samples': [{'id': 3,
#      'params': {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 6,
#      'params': {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 22,
#      'params': {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 47,
#      'params': {'sle': 4.6,
#       'swi': 3.2,
#       'ple': 1.4,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 4.7,
#    'samples': [{'id': 2,
#      'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 29,
#      'params': {'sle': 4.7,
#       'swi': 3.2,
#       'ple': 1.6,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 4.8,
#    'samples': [{'id': 11,
#      'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 12,
#      'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 24,
#      'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 30,
#      'params': {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 45,
#      'params': {'sle': 4.8,
#       'swi': 3.0,
#       'ple': 1.4,
#       'pwi': 0.3,
#       'class': 0.0}}]},
#   {'value': 4.9,
#    'samples': [{'id': 1,
#      'params': {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 9,
#      'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 34,
#      'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 37,
#      'params': {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 57,
#      'params': {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 106,
#      'params': {'sle': 4.9,
#       'swi': 2.5,
#       'ple': 4.5,
#       'pwi': 1.7,
#       'class': 2.0}}]},
#   {'value': 5.0,
#    'samples': [{'id': 4,
#      'params': {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 7,
#      'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 25,
#      'params': {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 26,
#      'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 35,
#      'params': {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 40,
#      'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 43,
#      'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0}},
#     {'id': 49,
#      'params': {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 60,
#      'params': {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 93,
#      'params': {'sle': 5.0,
#       'swi': 2.3,
#       'ple': 3.3,
#       'pwi': 1.0,
#       'class': 1.0}}]},
#   {'value': 5.1,
#    'samples': [{'id': 0,
#      'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 17,
#      'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 19,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 21,
#      'params': {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 23,
#      'params': {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0}},
#     {'id': 39,
#      'params': {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 44,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 46,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 98,
#      'params': {'sle': 5.1,
#       'swi': 2.5,
#       'ple': 3.0,
#       'pwi': 1.1,
#       'class': 1.0}}]},
#   {'value': 5.2,
#    'samples': [{'id': 27,
#      'params': {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 28,
#      'params': {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 32,
#      'params': {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 59,
#      'params': {'sle': 5.2,
#       'swi': 2.7,
#       'ple': 3.9,
#       'pwi': 1.4,
#       'class': 1.0}}]},
#   {'value': 5.3,
#    'samples': [{'id': 48,
#      'params': {'sle': 5.3,
#       'swi': 3.7,
#       'ple': 1.5,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 5.4,
#    'samples': [{'id': 5,
#      'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 10,
#      'params': {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 16,
#      'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 20,
#      'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 31,
#      'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 84,
#      'params': {'sle': 5.4,
#       'swi': 3.0,
#       'ple': 4.5,
#       'pwi': 1.5,
#       'class': 1.0}}]},
#   {'value': 5.5,
#    'samples': [{'id': 33,
#      'params': {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 36,
#      'params': {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 53,
#      'params': {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 80,
#      'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0}},
#     {'id': 81,
#      'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 89,
#      'params': {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 90,
#      'params': {'sle': 5.5,
#       'swi': 2.6,
#       'ple': 4.4,
#       'pwi': 1.2,
#       'class': 1.0}}]},
#   {'value': 5.6,
#    'samples': [{'id': 64,
#      'params': {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 66,
#      'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 69,
#      'params': {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0}},
#     {'id': 88,
#      'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 94,
#      'params': {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 121,
#      'params': {'sle': 5.6,
#       'swi': 2.8,
#       'ple': 4.9,
#       'pwi': 2.0,
#       'class': 2.0}}]},
#   {'value': 5.7,
#    'samples': [{'id': 15,
#      'params': {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 18,
#      'params': {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 55,
#      'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 79,
#      'params': {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 95,
#      'params': {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 96,
#      'params': {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 99,
#      'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 113,
#      'params': {'sle': 5.7,
#       'swi': 2.5,
#       'ple': 5.0,
#       'pwi': 2.0,
#       'class': 2.0}}]},
#   {'value': 5.8,
#    'samples': [{'id': 14,
#      'params': {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 67,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 82,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 92,
#      'params': {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 101,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 114,
#      'params': {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 142,
#      'params': {'sle': 5.8,
#       'swi': 2.7,
#       'ple': 5.1,
#       'pwi': 1.9,
#       'class': 2.0}}]},
#   {'value': 5.9,
#    'samples': [{'id': 61,
#      'params': {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 70,
#      'params': {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0}},
#     {'id': 149,
#      'params': {'sle': 5.9,
#       'swi': 3.0,
#       'ple': 5.1,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 6.0,
#    'samples': [{'id': 62,
#      'params': {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 78,
#      'params': {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 83,
#      'params': {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 85,
#      'params': {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 119,
#      'params': {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0}},
#     {'id': 138,
#      'params': {'sle': 6.0,
#       'swi': 3.0,
#       'ple': 4.8,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 6.1,
#    'samples': [{'id': 63,
#      'params': {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 71,
#      'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 73,
#      'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 91,
#      'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 127,
#      'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 134,
#      'params': {'sle': 6.1,
#       'swi': 2.6,
#       'ple': 5.6,
#       'pwi': 1.4,
#       'class': 2.0}}]},
#   {'value': 6.2,
#    'samples': [{'id': 68,
#      'params': {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 97,
#      'params': {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 126,
#      'params': {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 148,
#      'params': {'sle': 6.2,
#       'swi': 3.4,
#       'ple': 5.4,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 6.3,
#    'samples': [{'id': 56,
#      'params': {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 72,
#      'params': {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 87,
#      'params': {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 100,
#      'params': {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 103,
#      'params': {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 123,
#      'params': {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 133,
#      'params': {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0}},
#     {'id': 136,
#      'params': {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 146,
#      'params': {'sle': 6.3,
#       'swi': 2.5,
#       'ple': 5.0,
#       'pwi': 1.9,
#       'class': 2.0}}]},
#   {'value': 6.4,
#    'samples': [{'id': 51,
#      'params': {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 74,
#      'params': {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 111,
#      'params': {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 115,
#      'params': {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 128,
#      'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 132,
#      'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 137,
#      'params': {'sle': 6.4,
#       'swi': 3.1,
#       'ple': 5.5,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 6.5,
#    'samples': [{'id': 54,
#      'params': {'sle': 6.5, 'swi': 2.8, 'ple': 4.6, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 104,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 110,
#      'params': {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 116,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 147,
#      'params': {'sle': 6.5,
#       'swi': 3.0,
#       'ple': 5.2,
#       'pwi': 2.0,
#       'class': 2.0}}]},
#   {'value': 6.6,
#    'samples': [{'id': 58,
#      'params': {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 75,
#      'params': {'sle': 6.6,
#       'swi': 3.0,
#       'ple': 4.4,
#       'pwi': 1.4,
#       'class': 1.0}}]},
#   {'value': 6.7,
#    'samples': [{'id': 65,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 77,
#      'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0}},
#     {'id': 86,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 108,
#      'params': {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 124,
#      'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 140,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 144,
#      'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 145,
#      'params': {'sle': 6.7,
#       'swi': 3.0,
#       'ple': 5.2,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 6.8,
#    'samples': [{'id': 76,
#      'params': {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 112,
#      'params': {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 143,
#      'params': {'sle': 6.8,
#       'swi': 3.2,
#       'ple': 5.9,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 6.9,
#    'samples': [{'id': 52,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 120,
#      'params': {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 139,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 141,
#      'params': {'sle': 6.9,
#       'swi': 3.1,
#       'ple': 5.1,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 7.0,
#    'samples': [{'id': 50,
#      'params': {'sle': 7.0,
#       'swi': 3.2,
#       'ple': 4.7,
#       'pwi': 1.4,
#       'class': 1.0}}]},
#   {'value': 7.1,
#    'samples': [{'id': 102,
#      'params': {'sle': 7.1,
#       'swi': 3.0,
#       'ple': 5.9,
#       'pwi': 2.1,
#       'class': 2.0}}]},
#   {'value': 7.2,
#    'samples': [{'id': 109,
#      'params': {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 125,
#      'params': {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 129,
#      'params': {'sle': 7.2,
#       'swi': 3.0,
#       'ple': 5.8,
#       'pwi': 1.6,
#       'class': 2.0}}]},
#   {'value': 7.3,
#    'samples': [{'id': 107,
#      'params': {'sle': 7.3,
#       'swi': 2.9,
#       'ple': 6.3,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 7.4,
#    'samples': [{'id': 130,
#      'params': {'sle': 7.4,
#       'swi': 2.8,
#       'ple': 6.1,
#       'pwi': 1.9,
#       'class': 2.0}}]},
#   {'value': 7.6,
#    'samples': [{'id': 105,
#      'params': {'sle': 7.6,
#       'swi': 3.0,
#       'ple': 6.6,
#       'pwi': 2.1,
#       'class': 2.0}}]},
#   {'value': 7.7,
#    'samples': [{'id': 117,
#      'params': {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 118,
#      'params': {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 122,
#      'params': {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 135,
#      'params': {'sle': 7.7,
#       'swi': 3.0,
#       'ple': 6.1,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 7.9,
#    'samples': [{'id': 131,
#      'params': {'sle': 7.9,
#       'swi': 3.8,
#       'ple': 6.4,
#       'pwi': 2.0,
#       'class': 2.0}}]}],
#  'swi': [{'value': 2.0,
#    'samples': [{'id': 60,
#      'params': {'sle': 5.0,
#       'swi': 2.0,
#       'ple': 3.5,
#       'pwi': 1.0,
#       'class': 1.0}}]},
#   {'value': 2.2,
#    'samples': [{'id': 62,
#      'params': {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 68,
#      'params': {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 119,
#      'params': {'sle': 6.0,
#       'swi': 2.2,
#       'ple': 5.0,
#       'pwi': 1.5,
#       'class': 2.0}}]},
#   {'value': 2.3,
#    'samples': [{'id': 41,
#      'params': {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 53,
#      'params': {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 87,
#      'params': {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 93,
#      'params': {'sle': 5.0,
#       'swi': 2.3,
#       'ple': 3.3,
#       'pwi': 1.0,
#       'class': 1.0}}]},
#   {'value': 2.4,
#    'samples': [{'id': 57,
#      'params': {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 80,
#      'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0}},
#     {'id': 81,
#      'params': {'sle': 5.5,
#       'swi': 2.4,
#       'ple': 3.7,
#       'pwi': 1.0,
#       'class': 1.0}}]},
#   {'value': 2.5,
#    'samples': [{'id': 69,
#      'params': {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0}},
#     {'id': 72,
#      'params': {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 89,
#      'params': {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 98,
#      'params': {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0}},
#     {'id': 106,
#      'params': {'sle': 4.9, 'swi': 2.5, 'ple': 4.5, 'pwi': 1.7, 'class': 2.0}},
#     {'id': 108,
#      'params': {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 113,
#      'params': {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 146,
#      'params': {'sle': 6.3,
#       'swi': 2.5,
#       'ple': 5.0,
#       'pwi': 1.9,
#       'class': 2.0}}]},
#   {'value': 2.6,
#    'samples': [{'id': 79,
#      'params': {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 90,
#      'params': {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 92,
#      'params': {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 118,
#      'params': {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 134,
#      'params': {'sle': 6.1,
#       'swi': 2.6,
#       'ple': 5.6,
#       'pwi': 1.4,
#       'class': 2.0}}]},
#   {'value': 2.7,
#    'samples': [{'id': 59,
#      'params': {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 67,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 82,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 83,
#      'params': {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 94,
#      'params': {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 101,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 111,
#      'params': {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 123,
#      'params': {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 142,
#      'params': {'sle': 5.8,
#       'swi': 2.7,
#       'ple': 5.1,
#       'pwi': 1.9,
#       'class': 2.0}}]},
#   {'value': 2.8,
#    'samples': [{'id': 54,
#      'params': {'sle': 6.5, 'swi': 2.8, 'ple': 4.6, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 55,
#      'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 71,
#      'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 73,
#      'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 76,
#      'params': {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 99,
#      'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 114,
#      'params': {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 121,
#      'params': {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 122,
#      'params': {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 126,
#      'params': {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 128,
#      'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 130,
#      'params': {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 132,
#      'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 133,
#      'params': {'sle': 6.3,
#       'swi': 2.8,
#       'ple': 5.1,
#       'pwi': 1.5,
#       'class': 2.0}}]},
#   {'value': 2.9,
#    'samples': [{'id': 8,
#      'params': {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 58,
#      'params': {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 63,
#      'params': {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 64,
#      'params': {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 74,
#      'params': {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 78,
#      'params': {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 96,
#      'params': {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 97,
#      'params': {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 103,
#      'params': {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 107,
#      'params': {'sle': 7.3,
#       'swi': 2.9,
#       'ple': 6.3,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 3.0,
#    'samples': [{'id': 1,
#      'params': {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 12,
#      'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 13,
#      'params': {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 25,
#      'params': {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 38,
#      'params': {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 45,
#      'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 61,
#      'params': {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 66,
#      'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 75,
#      'params': {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 77,
#      'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0}},
#     {'id': 84,
#      'params': {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 88,
#      'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 91,
#      'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 95,
#      'params': {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 102,
#      'params': {'sle': 7.1, 'swi': 3.0, 'ple': 5.9, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 104,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 105,
#      'params': {'sle': 7.6, 'swi': 3.0, 'ple': 6.6, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 112,
#      'params': {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 116,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 127,
#      'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 129,
#      'params': {'sle': 7.2, 'swi': 3.0, 'ple': 5.8, 'pwi': 1.6, 'class': 2.0}},
#     {'id': 135,
#      'params': {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 138,
#      'params': {'sle': 6.0, 'swi': 3.0, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 145,
#      'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 147,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 149,
#      'params': {'sle': 5.9,
#       'swi': 3.0,
#       'ple': 5.1,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 3.1,
#    'samples': [{'id': 3,
#      'params': {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 9,
#      'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 30,
#      'params': {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 34,
#      'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 52,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 65,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 86,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 137,
#      'params': {'sle': 6.4, 'swi': 3.1, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 139,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 140,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 141,
#      'params': {'sle': 6.9,
#       'swi': 3.1,
#       'ple': 5.1,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 3.2,
#    'samples': [{'id': 2,
#      'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 29,
#      'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 35,
#      'params': {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 42,
#      'params': {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 47,
#      'params': {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 50,
#      'params': {'sle': 7.0, 'swi': 3.2, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 51,
#      'params': {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 70,
#      'params': {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0}},
#     {'id': 110,
#      'params': {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 115,
#      'params': {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 120,
#      'params': {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 125,
#      'params': {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 143,
#      'params': {'sle': 6.8,
#       'swi': 3.2,
#       'ple': 5.9,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 3.3,
#    'samples': [{'id': 23,
#      'params': {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0}},
#     {'id': 49,
#      'params': {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 56,
#      'params': {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 100,
#      'params': {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 124,
#      'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 144,
#      'params': {'sle': 6.7,
#       'swi': 3.3,
#       'ple': 5.7,
#       'pwi': 2.5,
#       'class': 2.0}}]},
#   {'value': 3.4,
#    'samples': [{'id': 6,
#      'params': {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 7,
#      'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 11,
#      'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 20,
#      'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 24,
#      'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 26,
#      'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 28,
#      'params': {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 31,
#      'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 39,
#      'params': {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 85,
#      'params': {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 136,
#      'params': {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 148,
#      'params': {'sle': 6.2,
#       'swi': 3.4,
#       'ple': 5.4,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 3.5,
#    'samples': [{'id': 0,
#      'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 17,
#      'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 27,
#      'params': {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 36,
#      'params': {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 40,
#      'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 43,
#      'params': {'sle': 5.0,
#       'swi': 3.5,
#       'ple': 1.6,
#       'pwi': 0.6,
#       'class': 0.0}}]},
#   {'value': 3.6,
#    'samples': [{'id': 4,
#      'params': {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 22,
#      'params': {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 37,
#      'params': {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 109,
#      'params': {'sle': 7.2,
#       'swi': 3.6,
#       'ple': 6.1,
#       'pwi': 2.5,
#       'class': 2.0}}]},
#   {'value': 3.7,
#    'samples': [{'id': 10,
#      'params': {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 21,
#      'params': {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 48,
#      'params': {'sle': 5.3,
#       'swi': 3.7,
#       'ple': 1.5,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 3.8,
#    'samples': [{'id': 18,
#      'params': {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 19,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 44,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 46,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 117,
#      'params': {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 131,
#      'params': {'sle': 7.9,
#       'swi': 3.8,
#       'ple': 6.4,
#       'pwi': 2.0,
#       'class': 2.0}}]},
#   {'value': 3.9,
#    'samples': [{'id': 5,
#      'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 16,
#      'params': {'sle': 5.4,
#       'swi': 3.9,
#       'ple': 1.3,
#       'pwi': 0.4,
#       'class': 0.0}}]},
#   {'value': 4.0,
#    'samples': [{'id': 14,
#      'params': {'sle': 5.8,
#       'swi': 4.0,
#       'ple': 1.2,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 4.1,
#    'samples': [{'id': 32,
#      'params': {'sle': 5.2,
#       'swi': 4.1,
#       'ple': 1.5,
#       'pwi': 0.1,
#       'class': 0.0}}]},
#   {'value': 4.2,
#    'samples': [{'id': 33,
#      'params': {'sle': 5.5,
#       'swi': 4.2,
#       'ple': 1.4,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 4.4,
#    'samples': [{'id': 15,
#      'params': {'sle': 5.7,
#       'swi': 4.4,
#       'ple': 1.5,
#       'pwi': 0.4,
#       'class': 0.0}}]}],
#  'ple': [{'value': 1.0,
#    'samples': [{'id': 22,
#      'params': {'sle': 4.6,
#       'swi': 3.6,
#       'ple': 1.0,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 1.1,
#    'samples': [{'id': 13,
#      'params': {'sle': 4.3,
#       'swi': 3.0,
#       'ple': 1.1,
#       'pwi': 0.1,
#       'class': 0.0}}]},
#   {'value': 1.2,
#    'samples': [{'id': 14,
#      'params': {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 35,
#      'params': {'sle': 5.0,
#       'swi': 3.2,
#       'ple': 1.2,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 1.3,
#    'samples': [{'id': 2,
#      'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 16,
#      'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 36,
#      'params': {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 38,
#      'params': {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 40,
#      'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 41,
#      'params': {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 42,
#      'params': {'sle': 4.4,
#       'swi': 3.2,
#       'ple': 1.3,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 1.4,
#    'samples': [{'id': 0,
#      'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 1,
#      'params': {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 4,
#      'params': {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 6,
#      'params': {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 8,
#      'params': {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 12,
#      'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 17,
#      'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 28,
#      'params': {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 33,
#      'params': {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 37,
#      'params': {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 45,
#      'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 47,
#      'params': {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 49,
#      'params': {'sle': 5.0,
#       'swi': 3.3,
#       'ple': 1.4,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 1.5,
#    'samples': [{'id': 3,
#      'params': {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 7,
#      'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 9,
#      'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 10,
#      'params': {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 15,
#      'params': {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 19,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 21,
#      'params': {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 27,
#      'params': {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 31,
#      'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 32,
#      'params': {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 34,
#      'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 39,
#      'params': {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 48,
#      'params': {'sle': 5.3,
#       'swi': 3.7,
#       'ple': 1.5,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 1.6,
#    'samples': [{'id': 11,
#      'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 25,
#      'params': {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 26,
#      'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 29,
#      'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 30,
#      'params': {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 43,
#      'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0}},
#     {'id': 46,
#      'params': {'sle': 5.1,
#       'swi': 3.8,
#       'ple': 1.6,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 1.7,
#    'samples': [{'id': 5,
#      'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 18,
#      'params': {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 20,
#      'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 23,
#      'params': {'sle': 5.1,
#       'swi': 3.3,
#       'ple': 1.7,
#       'pwi': 0.5,
#       'class': 0.0}}]},
#   {'value': 1.9,
#    'samples': [{'id': 24,
#      'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 44,
#      'params': {'sle': 5.1,
#       'swi': 3.8,
#       'ple': 1.9,
#       'pwi': 0.4,
#       'class': 0.0}}]},
#   {'value': 3.0,
#    'samples': [{'id': 98,
#      'params': {'sle': 5.1,
#       'swi': 2.5,
#       'ple': 3.0,
#       'pwi': 1.1,
#       'class': 1.0}}]},
#   {'value': 3.3,
#    'samples': [{'id': 57,
#      'params': {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 93,
#      'params': {'sle': 5.0,
#       'swi': 2.3,
#       'ple': 3.3,
#       'pwi': 1.0,
#       'class': 1.0}}]},
#   {'value': 3.5,
#    'samples': [{'id': 60,
#      'params': {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 79,
#      'params': {'sle': 5.7,
#       'swi': 2.6,
#       'ple': 3.5,
#       'pwi': 1.0,
#       'class': 1.0}}]},
#   {'value': 3.6,
#    'samples': [{'id': 64,
#      'params': {'sle': 5.6,
#       'swi': 2.9,
#       'ple': 3.6,
#       'pwi': 1.3,
#       'class': 1.0}}]},
#   {'value': 3.7,
#    'samples': [{'id': 81,
#      'params': {'sle': 5.5,
#       'swi': 2.4,
#       'ple': 3.7,
#       'pwi': 1.0,
#       'class': 1.0}}]},
#   {'value': 3.8,
#    'samples': [{'id': 80,
#      'params': {'sle': 5.5,
#       'swi': 2.4,
#       'ple': 3.8,
#       'pwi': 1.1,
#       'class': 1.0}}]},
#   {'value': 3.9,
#    'samples': [{'id': 59,
#      'params': {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 69,
#      'params': {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0}},
#     {'id': 82,
#      'params': {'sle': 5.8,
#       'swi': 2.7,
#       'ple': 3.9,
#       'pwi': 1.2,
#       'class': 1.0}}]},
#   {'value': 4.0,
#    'samples': [{'id': 53,
#      'params': {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 62,
#      'params': {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 71,
#      'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 89,
#      'params': {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 92,
#      'params': {'sle': 5.8,
#       'swi': 2.6,
#       'ple': 4.0,
#       'pwi': 1.2,
#       'class': 1.0}}]},
#   {'value': 4.1,
#    'samples': [{'id': 67,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 88,
#      'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 99,
#      'params': {'sle': 5.7,
#       'swi': 2.8,
#       'ple': 4.1,
#       'pwi': 1.3,
#       'class': 1.0}}]},
#   {'value': 4.2,
#    'samples': [{'id': 61,
#      'params': {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 94,
#      'params': {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 95,
#      'params': {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 96,
#      'params': {'sle': 5.7,
#       'swi': 2.9,
#       'ple': 4.2,
#       'pwi': 1.3,
#       'class': 1.0}}]},
#   {'value': 4.3,
#    'samples': [{'id': 74,
#      'params': {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 97,
#      'params': {'sle': 6.2,
#       'swi': 2.9,
#       'ple': 4.3,
#       'pwi': 1.3,
#       'class': 1.0}}]},
#   {'value': 4.4,
#    'samples': [{'id': 65,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 75,
#      'params': {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 87,
#      'params': {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 90,
#      'params': {'sle': 5.5,
#       'swi': 2.6,
#       'ple': 4.4,
#       'pwi': 1.2,
#       'class': 1.0}}]},
#   {'value': 4.5,
#    'samples': [{'id': 51,
#      'params': {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 55,
#      'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 66,
#      'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 68,
#      'params': {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 78,
#      'params': {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 84,
#      'params': {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 85,
#      'params': {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 106,
#      'params': {'sle': 4.9,
#       'swi': 2.5,
#       'ple': 4.5,
#       'pwi': 1.7,
#       'class': 2.0}}]},
#   {'value': 4.6,
#    'samples': [{'id': 54,
#      'params': {'sle': 6.5, 'swi': 2.8, 'ple': 4.6, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 58,
#      'params': {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 91,
#      'params': {'sle': 6.1,
#       'swi': 3.0,
#       'ple': 4.6,
#       'pwi': 1.4,
#       'class': 1.0}}]},
#   {'value': 4.7,
#    'samples': [{'id': 50,
#      'params': {'sle': 7.0, 'swi': 3.2, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 56,
#      'params': {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 63,
#      'params': {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 73,
#      'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 86,
#      'params': {'sle': 6.7,
#       'swi': 3.1,
#       'ple': 4.7,
#       'pwi': 1.5,
#       'class': 1.0}}]},
#   {'value': 4.8,
#    'samples': [{'id': 70,
#      'params': {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0}},
#     {'id': 76,
#      'params': {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 126,
#      'params': {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 138,
#      'params': {'sle': 6.0,
#       'swi': 3.0,
#       'ple': 4.8,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 4.9,
#    'samples': [{'id': 52,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 72,
#      'params': {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 121,
#      'params': {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 123,
#      'params': {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 127,
#      'params': {'sle': 6.1,
#       'swi': 3.0,
#       'ple': 4.9,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 5.0,
#    'samples': [{'id': 77,
#      'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0}},
#     {'id': 113,
#      'params': {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 119,
#      'params': {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0}},
#     {'id': 146,
#      'params': {'sle': 6.3,
#       'swi': 2.5,
#       'ple': 5.0,
#       'pwi': 1.9,
#       'class': 2.0}}]},
#   {'value': 5.1,
#    'samples': [{'id': 83,
#      'params': {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 101,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 110,
#      'params': {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 114,
#      'params': {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 133,
#      'params': {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0}},
#     {'id': 141,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 142,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 149,
#      'params': {'sle': 5.9,
#       'swi': 3.0,
#       'ple': 5.1,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 5.2,
#    'samples': [{'id': 145,
#      'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 147,
#      'params': {'sle': 6.5,
#       'swi': 3.0,
#       'ple': 5.2,
#       'pwi': 2.0,
#       'class': 2.0}}]},
#   {'value': 5.3,
#    'samples': [{'id': 111,
#      'params': {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 115,
#      'params': {'sle': 6.4,
#       'swi': 3.2,
#       'ple': 5.3,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 5.4,
#    'samples': [{'id': 139,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 148,
#      'params': {'sle': 6.2,
#       'swi': 3.4,
#       'ple': 5.4,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 5.5,
#    'samples': [{'id': 112,
#      'params': {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 116,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 137,
#      'params': {'sle': 6.4,
#       'swi': 3.1,
#       'ple': 5.5,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 5.6,
#    'samples': [{'id': 103,
#      'params': {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 128,
#      'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 132,
#      'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 134,
#      'params': {'sle': 6.1, 'swi': 2.6, 'ple': 5.6, 'pwi': 1.4, 'class': 2.0}},
#     {'id': 136,
#      'params': {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 140,
#      'params': {'sle': 6.7,
#       'swi': 3.1,
#       'ple': 5.6,
#       'pwi': 2.4,
#       'class': 2.0}}]},
#   {'value': 5.7,
#    'samples': [{'id': 120,
#      'params': {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 124,
#      'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 144,
#      'params': {'sle': 6.7,
#       'swi': 3.3,
#       'ple': 5.7,
#       'pwi': 2.5,
#       'class': 2.0}}]},
#   {'value': 5.8,
#    'samples': [{'id': 104,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 108,
#      'params': {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 129,
#      'params': {'sle': 7.2,
#       'swi': 3.0,
#       'ple': 5.8,
#       'pwi': 1.6,
#       'class': 2.0}}]},
#   {'value': 5.9,
#    'samples': [{'id': 102,
#      'params': {'sle': 7.1, 'swi': 3.0, 'ple': 5.9, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 143,
#      'params': {'sle': 6.8,
#       'swi': 3.2,
#       'ple': 5.9,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 6.0,
#    'samples': [{'id': 100,
#      'params': {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 125,
#      'params': {'sle': 7.2,
#       'swi': 3.2,
#       'ple': 6.0,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 6.1,
#    'samples': [{'id': 109,
#      'params': {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 130,
#      'params': {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 135,
#      'params': {'sle': 7.7,
#       'swi': 3.0,
#       'ple': 6.1,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 6.3,
#    'samples': [{'id': 107,
#      'params': {'sle': 7.3,
#       'swi': 2.9,
#       'ple': 6.3,
#       'pwi': 1.8,
#       'class': 2.0}}]},
#   {'value': 6.4,
#    'samples': [{'id': 131,
#      'params': {'sle': 7.9,
#       'swi': 3.8,
#       'ple': 6.4,
#       'pwi': 2.0,
#       'class': 2.0}}]},
#   {'value': 6.6,
#    'samples': [{'id': 105,
#      'params': {'sle': 7.6,
#       'swi': 3.0,
#       'ple': 6.6,
#       'pwi': 2.1,
#       'class': 2.0}}]},
#   {'value': 6.7,
#    'samples': [{'id': 117,
# ...
#       'class': 2.0}}]},
#   {'value': 2.3,
#    'samples': [{'id': 115,
#      'params': {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 118,
#      'params': {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 120,
#      'params': {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 135,
#      'params': {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 141,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 143,
#      'params': {'sle': 6.8, 'swi': 3.2, 'ple': 5.9, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 145,
#      'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 148,
#      'params': {'sle': 6.2,
#       'swi': 3.4,
#       'ple': 5.4,
#       'pwi': 2.3,
#       'class': 2.0}}]},
#   {'value': 2.4,
#    'samples': [{'id': 114,
#      'params': {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 136,
#      'params': {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 140,
#      'params': {'sle': 6.7,
#       'swi': 3.1,
#       'ple': 5.6,
#       'pwi': 2.4,
#       'class': 2.0}}]},
#   {'value': 2.5,
#    'samples': [{'id': 100,
#      'params': {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 109,
#      'params': {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 144,
#      'params': {'sle': 6.7,
#       'swi': 3.3,
#       'ple': 5.7,
#       'pwi': 2.5,
#       'class': 2.0}}]}],
#  'class': [{'value': 0,
#    'samples': [{'id': 0,
#      'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 1,
#      'params': {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 2,
#      'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 3,
#      'params': {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 4,
#      'params': {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 5,
#      'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 6,
#      'params': {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 7,
#      'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 8,
#      'params': {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 9,
#      'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 10,
#      'params': {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 11,
#      'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 12,
#      'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 13,
#      'params': {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 14,
#      'params': {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 15,
#      'params': {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 16,
#      'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 17,
#      'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 18,
#      'params': {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 19,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 20,
#      'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 21,
#      'params': {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 22,
#      'params': {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 23,
#      'params': {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0}},
#     {'id': 24,
#      'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 25,
#      'params': {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 26,
#      'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 27,
#      'params': {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 28,
#      'params': {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 29,
#      'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 30,
#      'params': {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 31,
#      'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 32,
#      'params': {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 33,
#      'params': {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 34,
#      'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 35,
#      'params': {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 36,
#      'params': {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 37,
#      'params': {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0}},
#     {'id': 38,
#      'params': {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 39,
#      'params': {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 40,
#      'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 41,
#      'params': {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 42,
#      'params': {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 43,
#      'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0}},
#     {'id': 44,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0}},
#     {'id': 45,
#      'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0}},
#     {'id': 46,
#      'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 47,
#      'params': {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 48,
#      'params': {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0}},
#     {'id': 49,
#      'params': {'sle': 5.0,
#       'swi': 3.3,
#       'ple': 1.4,
#       'pwi': 0.2,
#       'class': 0.0}}]},
#   {'value': 1,
#    'samples': [{'id': 50,
#      'params': {'sle': 7.0, 'swi': 3.2, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 51,
#      'params': {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 52,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 53,
#      'params': {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 54,
#      'params': {'sle': 6.5, 'swi': 2.8, 'ple': 4.6, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 55,
#      'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 56,
#      'params': {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 57,
#      'params': {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 58,
#      'params': {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 59,
#      'params': {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 60,
#      'params': {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 61,
#      'params': {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 62,
#      'params': {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 63,
#      'params': {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 64,
#      'params': {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 65,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 66,
#      'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 67,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 68,
#      'params': {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 69,
#      'params': {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0}},
#     {'id': 70,
#      'params': {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0}},
#     {'id': 71,
#      'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 72,
#      'params': {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 73,
#      'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 74,
#      'params': {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 75,
#      'params': {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 76,
#      'params': {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 77,
#      'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0}},
#     {'id': 78,
#      'params': {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 79,
#      'params': {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 80,
#      'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0}},
#     {'id': 81,
#      'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 82,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 83,
#      'params': {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 84,
#      'params': {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 85,
#      'params': {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0}},
#     {'id': 86,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0}},
#     {'id': 87,
#      'params': {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 88,
#      'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 89,
#      'params': {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 90,
#      'params': {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 91,
#      'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0}},
#     {'id': 92,
#      'params': {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 93,
#      'params': {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0}},
#     {'id': 94,
#      'params': {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 95,
#      'params': {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0}},
#     {'id': 96,
#      'params': {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 97,
#      'params': {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0}},
#     {'id': 98,
#      'params': {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0}},
#     {'id': 99,
#      'params': {'sle': 5.7,
#       'swi': 2.8,
#       'ple': 4.1,
#       'pwi': 1.3,
#       'class': 1.0}}]},
#   {'value': 2,
#    'samples': [{'id': 100,
#      'params': {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 101,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 102,
#      'params': {'sle': 7.1, 'swi': 3.0, 'ple': 5.9, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 103,
#      'params': {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 104,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 105,
#      'params': {'sle': 7.6, 'swi': 3.0, 'ple': 6.6, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 106,
#      'params': {'sle': 4.9, 'swi': 2.5, 'ple': 4.5, 'pwi': 1.7, 'class': 2.0}},
#     {'id': 107,
#      'params': {'sle': 7.3, 'swi': 2.9, 'ple': 6.3, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 108,
#      'params': {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 109,
#      'params': {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 110,
#      'params': {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 111,
#      'params': {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 112,
#      'params': {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 113,
#      'params': {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 114,
#      'params': {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 115,
#      'params': {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 116,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 117,
#      'params': {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 118,
#      'params': {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 119,
#      'params': {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0}},
#     {'id': 120,
#      'params': {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 121,
#      'params': {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 122,
#      'params': {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 123,
#      'params': {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 124,
#      'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 125,
#      'params': {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 126,
#      'params': {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 127,
#      'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 128,
#      'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 129,
#      'params': {'sle': 7.2, 'swi': 3.0, 'ple': 5.8, 'pwi': 1.6, 'class': 2.0}},
#     {'id': 130,
#      'params': {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 131,
#      'params': {'sle': 7.9, 'swi': 3.8, 'ple': 6.4, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 132,
#      'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0}},
#     {'id': 133,
#      'params': {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0}},
#     {'id': 134,
#      'params': {'sle': 6.1, 'swi': 2.6, 'ple': 5.6, 'pwi': 1.4, 'class': 2.0}},
#     {'id': 135,
#      'params': {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 136,
#      'params': {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 137,
#      'params': {'sle': 6.4, 'swi': 3.1, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 138,
#      'params': {'sle': 6.0, 'swi': 3.0, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0}},
#     {'id': 139,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0}},
#     {'id': 140,
#      'params': {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0}},
#     {'id': 141,
#      'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 142,
#      'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 143,
#      'params': {'sle': 6.8, 'swi': 3.2, 'ple': 5.9, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 144,
#      'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.5, 'class': 2.0}},
#     {'id': 145,
#      'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 146,
#      'params': {'sle': 6.3, 'swi': 2.5, 'ple': 5.0, 'pwi': 1.9, 'class': 2.0}},
#     {'id': 147,
#      'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.0, 'class': 2.0}},
#     {'id': 148,
#      'params': {'sle': 6.2, 'swi': 3.4, 'ple': 5.4, 'pwi': 2.3, 'class': 2.0}},
#     {'id': 149,
#      'params': {'sle': 5.9,
#       'swi': 3.0,
#       'ple': 5.1,
#       'pwi': 1.8,
#       'class': 2.0}}]}]}

# %%
def new_id(agds):
    samples = []
    for attr, params in agds.items():
        for param in params:
            for sample in param['samples']:
                samples += [sample]
    return max([s['id'] for s in samples]) + 1

def attach(sample, agds, samples):
    new_sample = {'id': new_id(agds), 'params': sample}
    
    cloned = agds
    
    for attr, params in cloned.items():
        param_value_found = False
        for param in params:
            if attr in sample and sample[attr] == param['value']:
                param['samples'].append(new_sample)
                param_value_found = True
        if attr in sample and not param_value_found:
            params.append({
                'value': sample[attr],
                'samples': [new_sample]
            })
            cloned[attr] = sorted(params, key=lambda a: a['value'])
            
    samples += [new_sample]
            
    return new_sample 
    

sample = {'swi': 1, 'sle': 4.4, 'pwi': 1, 'ple': 1}
attached = attach(sample, agds, samples)
attached
# Out:
# {'id': 150, 'params': {'swi': 1, 'sle': 4.4, 'pwi': 1, 'ple': 1}}

# %%
def init_weigths(agds, samples):
    for attr, params in agds.items():
        for param in params:
            param['weight'] = .0
    for sample in samples:
        sample['weight'] = .0
            
    return agds, samples

agds, samples = init_weigths(agds, samples)
agds, samples
# Out:
# ({'sle': [{'value': 4.3,
#     'samples': [{'id': 13,
#       'params': {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.4,
#     'samples': [{'id': 8,
#       'params': {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 38,
#       'params': {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 42,
#       'params': {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 150,
#       'params': {'swi': 1, 'sle': 4.4, 'pwi': 1, 'ple': 1},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.5,
#     'samples': [{'id': 41,
#       'params': {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.6,
#     'samples': [{'id': 3,
#       'params': {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 6,
#       'params': {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 22,
#       'params': {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 47,
#       'params': {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.7,
#     'samples': [{'id': 2,
#       'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 29,
#       'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.8,
#     'samples': [{'id': 11,
#       'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 12,
#       'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 24,
#       'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 30,
#       'params': {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 45,
#       'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.9,
#     'samples': [{'id': 1,
#       'params': {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 9,
#       'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 34,
#       'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 37,
#       'params': {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 57,
#       'params': {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 106,
#       'params': {'sle': 4.9, 'swi': 2.5, 'ple': 4.5, 'pwi': 1.7, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.0,
#     'samples': [{'id': 4,
#       'params': {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 7,
#       'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 25,
#       'params': {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 26,
#       'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 35,
#       'params': {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 40,
#       'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 43,
#       'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 49,
#       'params': {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 60,
#       'params': {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 93,
#       'params': {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.1,
#     'samples': [{'id': 0,
#       'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 17,
#       'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 19,
#       'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 21,
#       'params': {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 23,
#       'params': {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 39,
#       'params': {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 44,
#       'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 46,
#       'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 98,
#       'params': {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.2,
#     'samples': [{'id': 27,
#       'params': {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 28,
#       'params': {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 32,
#       'params': {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 59,
#       'params': {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.3,
#     'samples': [{'id': 48,
#       'params': {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.4,
#     'samples': [{'id': 5,
#       'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 10,
#       'params': {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 16,
#       'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 20,
#       'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 31,
#       'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 84,
#       'params': {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.5,
#     'samples': [{'id': 33,
#       'params': {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 36,
#       'params': {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 53,
#       'params': {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 80,
#       'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 81,
#       'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 89,
#       'params': {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 90,
#       'params': {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.6,
#     'samples': [{'id': 64,
#       'params': {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 66,
#       'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 69,
#       'params': {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 88,
#       'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 94,
#       'params': {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 121,
#       'params': {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.7,
#     'samples': [{'id': 15,
#       'params': {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 18,
#       'params': {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 55,
#       'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 79,
#       'params': {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 95,
#       'params': {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 96,
#       'params': {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 99,
#       'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 113,
#       'params': {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.8,
#     'samples': [{'id': 14,
#       'params': {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 67,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 82,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 92,
#       'params': {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 101,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 114,
#       'params': {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 142,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 5.9,
#     'samples': [{'id': 61,
#       'params': {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 70,
#       'params': {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 149,
#       'params': {'sle': 5.9, 'swi': 3.0, 'ple': 5.1, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.0,
#     'samples': [{'id': 62,
#       'params': {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 78,
#       'params': {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 83,
#       'params': {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 85,
#       'params': {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 119,
#       'params': {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 138,
#       'params': {'sle': 6.0, 'swi': 3.0, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.1,
#     'samples': [{'id': 63,
#       'params': {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 71,
#       'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 73,
#       'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 91,
#       'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 127,
#       'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 134,
#       'params': {'sle': 6.1, 'swi': 2.6, 'ple': 5.6, 'pwi': 1.4, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.2,
#     'samples': [{'id': 68,
#       'params': {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 97,
#       'params': {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 126,
#       'params': {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 148,
#       'params': {'sle': 6.2, 'swi': 3.4, 'ple': 5.4, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.3,
#     'samples': [{'id': 56,
#       'params': {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 72,
#       'params': {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 87,
#       'params': {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 100,
#       'params': {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 103,
#       'params': {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 123,
#       'params': {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 133,
#       'params': {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 136,
#       'params': {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 146,
#       'params': {'sle': 6.3, 'swi': 2.5, 'ple': 5.0, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.4,
#     'samples': [{'id': 51,
#       'params': {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 74,
#       'params': {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 111,
#       'params': {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 115,
#       'params': {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 128,
#       'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 132,
#       'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 137,
#       'params': {'sle': 6.4, 'swi': 3.1, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.5,
#     'samples': [{'id': 54,
#       'params': {'sle': 6.5, 'swi': 2.8, 'ple': 4.6, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 104,
#       'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 110,
#       'params': {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 116,
#       'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 147,
#       'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.6,
#     'samples': [{'id': 58,
#       'params': {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 75,
#       'params': {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.7,
#     'samples': [{'id': 65,
#       'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 77,
#       'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 86,
#       'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 108,
#       'params': {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 124,
#       'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 140,
#       'params': {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 144,
#       'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.5, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 145,
#       'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.8,
#     'samples': [{'id': 76,
#       'params': {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 112,
#       'params': {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 143,
#       'params': {'sle': 6.8, 'swi': 3.2, 'ple': 5.9, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 6.9,
#     'samples': [{'id': 52,
#       'params': {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 120,
#       'params': {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 139,
#       'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 141,
#       'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 7.0,
#     'samples': [{'id': 50,
#       'params': {'sle': 7.0, 'swi': 3.2, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 7.1,
#     'samples': [{'id': 102,
#       'params': {'sle': 7.1, 'swi': 3.0, 'ple': 5.9, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 7.2,
#     'samples': [{'id': 109,
#       'params': {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 125,
#       'params': {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 129,
#       'params': {'sle': 7.2, 'swi': 3.0, 'ple': 5.8, 'pwi': 1.6, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 7.3,
#     'samples': [{'id': 107,
#       'params': {'sle': 7.3, 'swi': 2.9, 'ple': 6.3, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 7.4,
#     'samples': [{'id': 130,
#       'params': {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 7.6,
#     'samples': [{'id': 105,
#       'params': {'sle': 7.6, 'swi': 3.0, 'ple': 6.6, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 7.7,
#     'samples': [{'id': 117,
#       'params': {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 118,
#       'params': {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 122,
#       'params': {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 135,
#       'params': {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 7.9,
#     'samples': [{'id': 131,
#       'params': {'sle': 7.9, 'swi': 3.8, 'ple': 6.4, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0}],
#   'swi': [{'value': 1,
#     'samples': [{'id': 150,
#       'params': {'swi': 1, 'sle': 4.4, 'pwi': 1, 'ple': 1},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 2.0,
#     'samples': [{'id': 60,
#       'params': {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 2.2,
#     'samples': [{'id': 62,
#       'params': {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 68,
#       'params': {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 119,
#       'params': {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 2.3,
#     'samples': [{'id': 41,
#       'params': {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 53,
#       'params': {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 87,
#       'params': {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 93,
#       'params': {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 2.4,
#     'samples': [{'id': 57,
#       'params': {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 80,
#       'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 81,
#       'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 2.5,
#     'samples': [{'id': 69,
#       'params': {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 72,
#       'params': {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 89,
#       'params': {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 98,
#       'params': {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 106,
#       'params': {'sle': 4.9, 'swi': 2.5, 'ple': 4.5, 'pwi': 1.7, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 108,
#       'params': {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 113,
#       'params': {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 146,
#       'params': {'sle': 6.3, 'swi': 2.5, 'ple': 5.0, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 2.6,
#     'samples': [{'id': 79,
#       'params': {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 90,
#       'params': {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 92,
#       'params': {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 118,
#       'params': {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 134,
#       'params': {'sle': 6.1, 'swi': 2.6, 'ple': 5.6, 'pwi': 1.4, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 2.7,
#     'samples': [{'id': 59,
#       'params': {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 67,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 82,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 83,
#       'params': {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 94,
#       'params': {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 101,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 111,
#       'params': {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 123,
#       'params': {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 142,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 2.8,
#     'samples': [{'id': 54,
#       'params': {'sle': 6.5, 'swi': 2.8, 'ple': 4.6, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 55,
#       'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 71,
#       'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 73,
#       'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 76,
#       'params': {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 99,
#       'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 114,
#       'params': {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 121,
#       'params': {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 122,
#       'params': {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 126,
#       'params': {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 128,
#       'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 130,
#       'params': {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 132,
#       'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 133,
#       'params': {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 2.9,
#     'samples': [{'id': 8,
#       'params': {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 58,
#       'params': {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 63,
#       'params': {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 64,
#       'params': {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 74,
#       'params': {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 78,
#       'params': {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 96,
#       'params': {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 97,
#       'params': {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 103,
#       'params': {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 107,
#       'params': {'sle': 7.3, 'swi': 2.9, 'ple': 6.3, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.0,
#     'samples': [{'id': 1,
#       'params': {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 12,
#       'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 13,
#       'params': {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 25,
#       'params': {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 38,
#       'params': {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 45,
#       'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 61,
#       'params': {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 66,
#       'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 75,
#       'params': {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 77,
#       'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 84,
#       'params': {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 88,
#       'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 91,
#       'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 95,
#       'params': {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 102,
#       'params': {'sle': 7.1, 'swi': 3.0, 'ple': 5.9, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 104,
#       'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 105,
#       'params': {'sle': 7.6, 'swi': 3.0, 'ple': 6.6, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 112,
#       'params': {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 116,
#       'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 127,
#       'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 129,
#       'params': {'sle': 7.2, 'swi': 3.0, 'ple': 5.8, 'pwi': 1.6, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 135,
#       'params': {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 138,
#       'params': {'sle': 6.0, 'swi': 3.0, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 145,
#       'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 147,
#       'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 149,
#       'params': {'sle': 5.9, 'swi': 3.0, 'ple': 5.1, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.1,
#     'samples': [{'id': 3,
#       'params': {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 9,
#       'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 30,
#       'params': {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 34,
#       'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 52,
#       'params': {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 65,
#       'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 86,
#       'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 137,
#       'params': {'sle': 6.4, 'swi': 3.1, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 139,
#       'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 140,
#       'params': {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 141,
#       'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.2,
#     'samples': [{'id': 2,
#       'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 29,
#       'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 35,
#       'params': {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 42,
#       'params': {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 47,
#       'params': {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 50,
#       'params': {'sle': 7.0, 'swi': 3.2, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 51,
#       'params': {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 70,
#       'params': {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 110,
#       'params': {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 115,
#       'params': {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 120,
#       'params': {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 125,
#       'params': {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 143,
#       'params': {'sle': 6.8, 'swi': 3.2, 'ple': 5.9, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.3,
#     'samples': [{'id': 23,
#       'params': {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 49,
#       'params': {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 56,
#       'params': {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 100,
#       'params': {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 124,
#       'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 144,
#       'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.5, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.4,
#     'samples': [{'id': 6,
#       'params': {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 7,
#       'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 11,
#       'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 20,
#       'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 24,
#       'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 26,
#       'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 28,
#       'params': {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 31,
#       'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 39,
#       'params': {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 85,
#       'params': {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 136,
#       'params': {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 148,
#       'params': {'sle': 6.2, 'swi': 3.4, 'ple': 5.4, 'pwi': 2.3, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.5,
#     'samples': [{'id': 0,
#       'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 17,
#       'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 27,
#       'params': {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 36,
#       'params': {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 40,
#       'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 43,
#       'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.6,
#     'samples': [{'id': 4,
#       'params': {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 22,
#       'params': {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 37,
#       'params': {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 109,
#       'params': {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.7,
#     'samples': [{'id': 10,
#       'params': {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 21,
#       'params': {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 48,
#       'params': {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.8,
#     'samples': [{'id': 18,
#       'params': {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 19,
#       'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 44,
#       'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 46,
#       'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 117,
#       'params': {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0},
#       'weight': 0.0},
#      {'id': 131,
#       'params': {'sle': 7.9, 'swi': 3.8, 'ple': 6.4, 'pwi': 2.0, 'class': 2.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.9,
#     'samples': [{'id': 5,
#       'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 16,
#       'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.0,
#     'samples': [{'id': 14,
#       'params': {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.1,
#     'samples': [{'id': 32,
#       'params': {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.2,
#     'samples': [{'id': 33,
#       'params': {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.4,
#     'samples': [{'id': 15,
#       'params': {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0}],
#   'ple': [{'value': 1.0,
#     'samples': [{'id': 22,
#       'params': {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 150,
#       'params': {'swi': 1, 'sle': 4.4, 'pwi': 1, 'ple': 1},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 1.1,
#     'samples': [{'id': 13,
#       'params': {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 1.2,
#     'samples': [{'id': 14,
#       'params': {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 35,
#       'params': {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 1.3,
#     'samples': [{'id': 2,
#       'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 16,
#       'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 36,
#       'params': {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 38,
#       'params': {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 40,
#       'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 41,
#       'params': {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 42,
#       'params': {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 1.4,
#     'samples': [{'id': 0,
#       'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 1,
#       'params': {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 4,
#       'params': {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 6,
#       'params': {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 8,
#       'params': {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 12,
#       'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 17,
#       'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 28,
#       'params': {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 33,
#       'params': {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 37,
#       'params': {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 45,
#       'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 47,
#       'params': {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 49,
#       'params': {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 1.5,
#     'samples': [{'id': 3,
#       'params': {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 7,
#       'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 9,
#       'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 10,
#       'params': {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 15,
#       'params': {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 19,
#       'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 21,
#       'params': {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 27,
#       'params': {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 31,
#       'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 32,
#       'params': {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 34,
#       'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 39,
#       'params': {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 48,
#       'params': {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 1.6,
#     'samples': [{'id': 11,
#       'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 25,
#       'params': {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 26,
#       'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 29,
#       'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 30,
#       'params': {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 43,
#       'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 46,
#       'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 1.7,
#     'samples': [{'id': 5,
#       'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 18,
#       'params': {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 20,
#       'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 23,
#       'params': {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 1.9,
#     'samples': [{'id': 24,
#       'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0},
#       'weight': 0.0},
#      {'id': 44,
#       'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.0,
#     'samples': [{'id': 98,
#       'params': {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.3,
#     'samples': [{'id': 57,
#       'params': {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 93,
#       'params': {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.5,
#     'samples': [{'id': 60,
#       'params': {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 79,
#       'params': {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.6,
#     'samples': [{'id': 64,
#       'params': {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.7,
#     'samples': [{'id': 81,
#       'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.8,
#     'samples': [{'id': 80,
#       'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 3.9,
#     'samples': [{'id': 59,
#       'params': {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 69,
#       'params': {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 82,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.0,
#     'samples': [{'id': 53,
#       'params': {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 62,
#       'params': {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 71,
#       'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 89,
#       'params': {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 92,
#       'params': {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.1,
#     'samples': [{'id': 67,
#       'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 88,
#       'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 99,
#       'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0},
#       'weight': 0.0}],
#     'weight': 0.0},
#    {'value': 4.2,
#     'samples': [{'id': 61,
#       'params': {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0},
#       'weight': 0.0},
#      {'id': 94,
# ...
#    'weight': 0.0},
#   {'id': 5,
#    'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 6,
#    'params': {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 7,
#    'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 8,
#    'params': {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 9,
#    'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 10,
#    'params': {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 11,
#    'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 12,
#    'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 13,
#    'params': {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 14,
#    'params': {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 15,
#    'params': {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 16,
#    'params': {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 17,
#    'params': {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 18,
#    'params': {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 19,
#    'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 20,
#    'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 21,
#    'params': {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 22,
#    'params': {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 23,
#    'params': {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 24,
#    'params': {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 25,
#    'params': {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 26,
#    'params': {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 27,
#    'params': {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 28,
#    'params': {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 29,
#    'params': {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 30,
#    'params': {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 31,
#    'params': {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 32,
#    'params': {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 33,
#    'params': {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 34,
#    'params': {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 35,
#    'params': {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 36,
#    'params': {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 37,
#    'params': {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 38,
#    'params': {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 39,
#    'params': {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 40,
#    'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 41,
#    'params': {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 42,
#    'params': {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 43,
#    'params': {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 44,
#    'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 45,
#    'params': {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 46,
#    'params': {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 47,
#    'params': {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 48,
#    'params': {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 49,
#    'params': {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0},
#    'weight': 0.0},
#   {'id': 50,
#    'params': {'sle': 7.0, 'swi': 3.2, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 51,
#    'params': {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 52,
#    'params': {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 53,
#    'params': {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 54,
#    'params': {'sle': 6.5, 'swi': 2.8, 'ple': 4.6, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 55,
#    'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 56,
#    'params': {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 57,
#    'params': {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 58,
#    'params': {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 59,
#    'params': {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 60,
#    'params': {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 61,
#    'params': {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 62,
#    'params': {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 63,
#    'params': {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 64,
#    'params': {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 65,
#    'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 66,
#    'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 67,
#    'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 68,
#    'params': {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 69,
#    'params': {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 70,
#    'params': {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 71,
#    'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 72,
#    'params': {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 73,
#    'params': {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 74,
#    'params': {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 75,
#    'params': {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 76,
#    'params': {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 77,
#    'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 78,
#    'params': {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 79,
#    'params': {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 80,
#    'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 81,
#    'params': {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 82,
#    'params': {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 83,
#    'params': {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 84,
#    'params': {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 85,
#    'params': {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 86,
#    'params': {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 87,
#    'params': {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 88,
#    'params': {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 89,
#    'params': {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 90,
#    'params': {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 91,
#    'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 92,
#    'params': {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 93,
#    'params': {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 94,
#    'params': {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 95,
#    'params': {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 96,
#    'params': {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 97,
#    'params': {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 98,
#    'params': {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 99,
#    'params': {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0},
#    'weight': 0.0},
#   {'id': 100,
#    'params': {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 101,
#    'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 102,
#    'params': {'sle': 7.1, 'swi': 3.0, 'ple': 5.9, 'pwi': 2.1, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 103,
#    'params': {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 104,
#    'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 105,
#    'params': {'sle': 7.6, 'swi': 3.0, 'ple': 6.6, 'pwi': 2.1, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 106,
#    'params': {'sle': 4.9, 'swi': 2.5, 'ple': 4.5, 'pwi': 1.7, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 107,
#    'params': {'sle': 7.3, 'swi': 2.9, 'ple': 6.3, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 108,
#    'params': {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 109,
#    'params': {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 110,
#    'params': {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 111,
#    'params': {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 112,
#    'params': {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 113,
#    'params': {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 114,
#    'params': {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 115,
#    'params': {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 116,
#    'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 117,
#    'params': {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 118,
#    'params': {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 119,
#    'params': {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 120,
#    'params': {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 121,
#    'params': {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 122,
#    'params': {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 123,
#    'params': {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 124,
#    'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 125,
#    'params': {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 126,
#    'params': {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 127,
#    'params': {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 128,
#    'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 129,
#    'params': {'sle': 7.2, 'swi': 3.0, 'ple': 5.8, 'pwi': 1.6, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 130,
#    'params': {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 131,
#    'params': {'sle': 7.9, 'swi': 3.8, 'ple': 6.4, 'pwi': 2.0, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 132,
#    'params': {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 133,
#    'params': {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 134,
#    'params': {'sle': 6.1, 'swi': 2.6, 'ple': 5.6, 'pwi': 1.4, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 135,
#    'params': {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 136,
#    'params': {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 137,
#    'params': {'sle': 6.4, 'swi': 3.1, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 138,
#    'params': {'sle': 6.0, 'swi': 3.0, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 139,
#    'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 140,
#    'params': {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 141,
#    'params': {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 142,
#    'params': {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 143,
#    'params': {'sle': 6.8, 'swi': 3.2, 'ple': 5.9, 'pwi': 2.3, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 144,
#    'params': {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.5, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 145,
#    'params': {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 146,
#    'params': {'sle': 6.3, 'swi': 2.5, 'ple': 5.0, 'pwi': 1.9, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 147,
#    'params': {'sle': 6.5, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.0, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 148,
#    'params': {'sle': 6.2, 'swi': 3.4, 'ple': 5.4, 'pwi': 2.3, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 149,
#    'params': {'sle': 5.9, 'swi': 3.0, 'ple': 5.1, 'pwi': 1.8, 'class': 2.0},
#    'weight': 0.0},
#   {'id': 150,
#    'params': {'swi': 1, 'sle': 4.4, 'pwi': 1, 'ple': 1},
#    'weight': 0.0}])

# %%
def fill_value_weights(predicted, agds, samples):
    attached = attach(predicted, agds, samples)
    agds, samples = init_weigths(agds, samples)
    
    # init predicted sample and its value nodes with weights 1.0
    attached['weight'] = 1.0
    for attr, params in agds.items():
        idx = None
        if not attr in predicted:
            continue
        for i, param in enumerate(params):
            if param['value'] == predicted[attr]:
                param['weight'] = 1.0
                idx = i
                break
        # propagate weights back to the left
        for i in reversed(range(idx)):
            params[i]['weight'] = (1 - abs(params[i]['value'] - params[i+1]['value'])
                                   /(params[-1]['value'] - params[0]['value'])) * params[i+1]['weight']
        # propagate weights to the right
        for i in range(idx+1, len(params)):
            params[i]['weight'] = (1 - abs(params[i]['value'] - params[i-1]['value'])
                                   /(params[-1]['value'] - params[0]['value'])) * params[i-1]['weight']
        
    
    for sample in samples:
        param_weights = []
        for attr, value in sample['params'].items():
            for param in agds[attr]:
                if param['value'] == value:
                    param_weights += [param['weight']]
        sample['weight'] = sum([w / len(sample['params']) for w in param_weights])
    
    return agds, samples

def find_n_samples_with_max_weights(samples, n):
    return sorted(samples, reverse=True, key=lambda x: x['weight'])[:n]

agds, samples = fill_value_weights({'swi': 2.6, 'sle': 5.8, 'pwi': 1.2, 'ple': 4.0}, agds, samples)
find_n_samples_with_max_weights(samples, 5)
# Out:
# [{'id': 151,
#   'params': {'swi': 2.6, 'sle': 5.8, 'pwi': 1.2, 'ple': 4.0},
#   'weight': 1.0},
#  {'id': 152,
#   'params': {'swi': 2.6, 'sle': 5.8, 'pwi': 1.2, 'ple': 4.0},
#   'weight': 1.0},
#  {'id': 92,
#   'params': {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0},
#   'weight': 0.8},
#  {'id': 82,
#   'params': {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0},
#   'weight': 0.7907278165503491},
#  {'id': 67,
#   'params': {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0},
#   'weight': 0.7744083721059045}]

# %%
import functools
from collections import Counter

def predict(sample, X, y):
    df = pd.DataFrame(X)
    df['class'] = pd.Series(y)
    df.rename(columns={
        0: 'sle',
        1: 'swi',
        2: 'ple',
        3: 'pwi'
    }, inplace=True)
    
    entities = df.to_dict(orient='records')
    samples = []
    for idx,params in enumerate(entities):
        samples += [{
            'id': idx,
            'params': params
        }]
    agds = build_agds(df)
    
    agds, samples = fill_value_weights(sample, agds, samples)
    n_max = find_n_samples_with_max_weights(samples, 6)
    most_similar = list(filter(lambda x: 'class' in x['params'], n_max))
    
    return Counter(list(map(lambda x: x['params']['class'], most_similar))).most_common(1)[0][0]
 
predict({'swi': 2.6, 'sle': 5.8, 'pwi': 1.2, 'ple': 4.0}, iris_dataset['data'], iris_dataset['target'])
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], test_size=0.33)

tests_count = X_test.shape[0]
tests_passed = 0
for x,y in zip(X_test, y_test):
    predicted = predict({'swi': x[1], 'sle': x[0], 'pwi': x[3], 'ple': x[2]}, X_train, y_train)
    if int(predicted) == int(y):
        tests_passed += 1
        
print("Iris dataset splitted with 2:1 ratio. {0:.0%} of test set was recognized correctly.".format(tests_passed/ tests_count))
# Out:
# Iris dataset splitted with 2:1 ratio. 96% of test set was recognized correctly.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
import pandas as pd

# %matplotlib inline

# %%
iris_dataset = sklearn.datasets.load_iris()

df = pd.DataFrame(iris_dataset['data'])
df['class'] = pd.Series(iris_dataset.target)
df.rename(columns={
    0: 'sle',
    1: 'swi',
    2: 'ple',
    3: 'pwi'
}, inplace=True)

df.head()
samples = df.to_dict(orient='records')
for idx,sample in enumerate(samples):
    sample['id'] = idx

# %%
def build_agds(df):

    params = {}

    for param in df.columns.tolist():
        params.update({
            param: sorted(set(df[param].tolist()))
        })

    for (param, values) in params.items():
        connected_nodes = []
        for node in values:
            connected_nodes += [{
                    'value': node,
                    'samples': [sample for sample in samples if sample[param] == node]
                }]
            params[param] = connected_nodes

    return params

agds = build_agds(df)
agds
# Out:
# {'sle': [{'value': 4.3,
#    'samples': [{'sle': 4.3,
#      'swi': 3.0,
#      'ple': 1.1,
#      'pwi': 0.1,
#      'class': 0.0,
#      'id': 13}]},
#   {'value': 4.4,
#    'samples': [{'sle': 4.4,
#      'swi': 2.9,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 8},
#     {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 38},
#     {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 42}]},
#   {'value': 4.5,
#    'samples': [{'sle': 4.5,
#      'swi': 2.3,
#      'ple': 1.3,
#      'pwi': 0.3,
#      'class': 0.0,
#      'id': 41}]},
#   {'value': 4.6,
#    'samples': [{'sle': 4.6,
#      'swi': 3.1,
#      'ple': 1.5,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 3},
#     {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 6},
#     {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0, 'id': 22},
#     {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 47}]},
#   {'value': 4.7,
#    'samples': [{'sle': 4.7,
#      'swi': 3.2,
#      'ple': 1.3,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 2},
#     {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 29}]},
#   {'value': 4.8,
#    'samples': [{'sle': 4.8,
#      'swi': 3.4,
#      'ple': 1.6,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 11},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 12},
#     {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0, 'id': 24},
#     {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 30},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 45}]},
#   {'value': 4.9,
#    'samples': [{'sle': 4.9,
#      'swi': 3.0,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 1},
#     {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0, 'id': 9},
#     {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 34},
#     {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 37},
#     {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0, 'id': 57},
#     {'sle': 4.9,
#      'swi': 2.5,
#      'ple': 4.5,
#      'pwi': 1.7,
#      'class': 2.0,
#      'id': 106}]},
#   {'value': 5.0,
#    'samples': [{'sle': 5.0,
#      'swi': 3.6,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 4},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 7},
#     {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 25},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0, 'id': 26},
#     {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0, 'id': 35},
#     {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0, 'id': 40},
#     {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0, 'id': 43},
#     {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 49},
#     {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0, 'id': 60},
#     {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0, 'id': 93}]},
#   {'value': 5.1,
#    'samples': [{'sle': 5.1,
#      'swi': 3.5,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 0},
#     {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 17},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0, 'id': 19},
#     {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 21},
#     {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0, 'id': 23},
#     {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 39},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0, 'id': 44},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 46},
#     {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0, 'id': 98}]},
#   {'value': 5.2,
#    'samples': [{'sle': 5.2,
#      'swi': 3.5,
#      'ple': 1.5,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 27},
#     {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 28},
#     {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0, 'id': 32},
#     {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0, 'id': 59}]},
#   {'value': 5.3,
#    'samples': [{'sle': 5.3,
#      'swi': 3.7,
#      'ple': 1.5,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 48}]},
#   {'value': 5.4,
#    'samples': [{'sle': 5.4,
#      'swi': 3.9,
#      'ple': 1.7,
#      'pwi': 0.4,
#      'class': 0.0,
#      'id': 5},
#     {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 10},
#     {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0, 'id': 16},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0, 'id': 20},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 31},
#     {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 84}]},
#   {'value': 5.5,
#    'samples': [{'sle': 5.5,
#      'swi': 4.2,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 33},
#     {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 36},
#     {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 53},
#     {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0, 'id': 80},
#     {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0, 'id': 81},
#     {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 89},
#     {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0, 'id': 90}]},
#   {'value': 5.6,
#    'samples': [{'sle': 5.6,
#      'swi': 2.9,
#      'ple': 3.6,
#      'pwi': 1.3,
#      'class': 1.0,
#      'id': 64},
#     {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 66},
#     {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0, 'id': 69},
#     {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0, 'id': 88},
#     {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0, 'id': 94},
#     {'sle': 5.6,
#      'swi': 2.8,
#      'ple': 4.9,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 121}]},
#   {'value': 5.7,
#    'samples': [{'sle': 5.7,
#      'swi': 4.4,
#      'ple': 1.5,
#      'pwi': 0.4,
#      'class': 0.0,
#      'id': 15},
#     {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0, 'id': 18},
#     {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0, 'id': 55},
#     {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0, 'id': 79},
#     {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0, 'id': 95},
#     {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0, 'id': 96},
#     {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0, 'id': 99},
#     {'sle': 5.7,
#      'swi': 2.5,
#      'ple': 5.0,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 113}]},
#   {'value': 5.8,
#    'samples': [{'sle': 5.8,
#      'swi': 4.0,
#      'ple': 1.2,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 14},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0, 'id': 67},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0, 'id': 82},
#     {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0, 'id': 92},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0, 'id': 101},
#     {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0, 'id': 114},
#     {'sle': 5.8,
#      'swi': 2.7,
#      'ple': 5.1,
#      'pwi': 1.9,
#      'class': 2.0,
#      'id': 142}]},
#   {'value': 5.9,
#    'samples': [{'sle': 5.9,
#      'swi': 3.0,
#      'ple': 4.2,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 61},
#     {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0, 'id': 70},
#     {'sle': 5.9,
#      'swi': 3.0,
#      'ple': 5.1,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 149}]},
#   {'value': 6.0,
#    'samples': [{'sle': 6.0,
#      'swi': 2.2,
#      'ple': 4.0,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 62},
#     {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 78},
#     {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0, 'id': 83},
#     {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0, 'id': 85},
#     {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0, 'id': 119},
#     {'sle': 6.0,
#      'swi': 3.0,
#      'ple': 4.8,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 138}]},
#   {'value': 6.1,
#    'samples': [{'sle': 6.1,
#      'swi': 2.9,
#      'ple': 4.7,
#      'pwi': 1.4,
#      'class': 1.0,
#      'id': 63},
#     {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 71},
#     {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0, 'id': 73},
#     {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0, 'id': 91},
#     {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0, 'id': 127},
#     {'sle': 6.1,
#      'swi': 2.6,
#      'ple': 5.6,
#      'pwi': 1.4,
#      'class': 2.0,
#      'id': 134}]},
#   {'value': 6.2,
#    'samples': [{'sle': 6.2,
#      'swi': 2.2,
#      'ple': 4.5,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 68},
#     {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0, 'id': 97},
#     {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0, 'id': 126},
#     {'sle': 6.2,
#      'swi': 3.4,
#      'ple': 5.4,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 148}]},
#   {'value': 6.3,
#    'samples': [{'sle': 6.3,
#      'swi': 3.3,
#      'ple': 4.7,
#      'pwi': 1.6,
#      'class': 1.0,
#      'id': 56},
#     {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0, 'id': 72},
#     {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0, 'id': 87},
#     {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0, 'id': 100},
#     {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0, 'id': 103},
#     {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0, 'id': 123},
#     {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0, 'id': 133},
#     {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0, 'id': 136},
#     {'sle': 6.3,
#      'swi': 2.5,
#      'ple': 5.0,
#      'pwi': 1.9,
#      'class': 2.0,
#      'id': 146}]},
#   {'value': 6.4,
#    'samples': [{'sle': 6.4,
#      'swi': 3.2,
#      'ple': 4.5,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 51},
#     {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0, 'id': 74},
#     {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0, 'id': 111},
#     {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0, 'id': 115},
#     {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0, 'id': 128},
#     {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0, 'id': 132},
#     {'sle': 6.4,
#      'swi': 3.1,
#      'ple': 5.5,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 137}]},
#   {'value': 6.5,
#    'samples': [{'sle': 6.5,
#      'swi': 2.8,
#      'ple': 4.6,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 54},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0, 'id': 104},
#     {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0, 'id': 110},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0, 'id': 116},
#     {'sle': 6.5,
#      'swi': 3.0,
#      'ple': 5.2,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 147}]},
#   {'value': 6.6,
#    'samples': [{'sle': 6.6,
#      'swi': 2.9,
#      'ple': 4.6,
#      'pwi': 1.3,
#      'class': 1.0,
#      'id': 58},
#     {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0, 'id': 75}]},
#   {'value': 6.7,
#    'samples': [{'sle': 6.7,
#      'swi': 3.1,
#      'ple': 4.4,
#      'pwi': 1.4,
#      'class': 1.0,
#      'id': 65},
#     {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0, 'id': 77},
#     {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0, 'id': 86},
#     {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0, 'id': 108},
#     {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0, 'id': 124},
#     {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0, 'id': 140},
#     {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.5, 'class': 2.0, 'id': 144},
#     {'sle': 6.7,
#      'swi': 3.0,
#      'ple': 5.2,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 145}]},
#   {'value': 6.8,
#    'samples': [{'sle': 6.8,
#      'swi': 2.8,
#      'ple': 4.8,
#      'pwi': 1.4,
#      'class': 1.0,
#      'id': 76},
#     {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0, 'id': 112},
#     {'sle': 6.8,
#      'swi': 3.2,
#      'ple': 5.9,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 143}]},
#   {'value': 6.9,
#    'samples': [{'sle': 6.9,
#      'swi': 3.1,
#      'ple': 4.9,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 52},
#     {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0, 'id': 120},
#     {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0, 'id': 139},
#     {'sle': 6.9,
#      'swi': 3.1,
#      'ple': 5.1,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 141}]},
#   {'value': 7.0,
#    'samples': [{'sle': 7.0,
#      'swi': 3.2,
#      'ple': 4.7,
#      'pwi': 1.4,
#      'class': 1.0,
#      'id': 50}]},
#   {'value': 7.1,
#    'samples': [{'sle': 7.1,
#      'swi': 3.0,
#      'ple': 5.9,
#      'pwi': 2.1,
#      'class': 2.0,
#      'id': 102}]},
#   {'value': 7.2,
#    'samples': [{'sle': 7.2,
#      'swi': 3.6,
#      'ple': 6.1,
#      'pwi': 2.5,
#      'class': 2.0,
#      'id': 109},
#     {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0, 'id': 125},
#     {'sle': 7.2,
#      'swi': 3.0,
#      'ple': 5.8,
#      'pwi': 1.6,
#      'class': 2.0,
#      'id': 129}]},
#   {'value': 7.3,
#    'samples': [{'sle': 7.3,
#      'swi': 2.9,
#      'ple': 6.3,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 107}]},
#   {'value': 7.4,
#    'samples': [{'sle': 7.4,
#      'swi': 2.8,
#      'ple': 6.1,
#      'pwi': 1.9,
#      'class': 2.0,
#      'id': 130}]},
#   {'value': 7.6,
#    'samples': [{'sle': 7.6,
#      'swi': 3.0,
#      'ple': 6.6,
#      'pwi': 2.1,
#      'class': 2.0,
#      'id': 105}]},
#   {'value': 7.7,
#    'samples': [{'sle': 7.7,
#      'swi': 3.8,
#      'ple': 6.7,
#      'pwi': 2.2,
#      'class': 2.0,
#      'id': 117},
#     {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0, 'id': 118},
#     {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0, 'id': 122},
#     {'sle': 7.7,
#      'swi': 3.0,
#      'ple': 6.1,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 135}]},
#   {'value': 7.9,
#    'samples': [{'sle': 7.9,
#      'swi': 3.8,
#      'ple': 6.4,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 131}]}],
#  'swi': [{'value': 2.0,
#    'samples': [{'sle': 5.0,
#      'swi': 2.0,
#      'ple': 3.5,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 60}]},
#   {'value': 2.2,
#    'samples': [{'sle': 6.0,
#      'swi': 2.2,
#      'ple': 4.0,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 62},
#     {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 68},
#     {'sle': 6.0,
#      'swi': 2.2,
#      'ple': 5.0,
#      'pwi': 1.5,
#      'class': 2.0,
#      'id': 119}]},
#   {'value': 2.3,
#    'samples': [{'sle': 4.5,
#      'swi': 2.3,
#      'ple': 1.3,
#      'pwi': 0.3,
#      'class': 0.0,
#      'id': 41},
#     {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 53},
#     {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0, 'id': 87},
#     {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0, 'id': 93}]},
#   {'value': 2.4,
#    'samples': [{'sle': 4.9,
#      'swi': 2.4,
#      'ple': 3.3,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 57},
#     {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0, 'id': 80},
#     {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0, 'id': 81}]},
#   {'value': 2.5,
#    'samples': [{'sle': 5.6,
#      'swi': 2.5,
#      'ple': 3.9,
#      'pwi': 1.1,
#      'class': 1.0,
#      'id': 69},
#     {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0, 'id': 72},
#     {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 89},
#     {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0, 'id': 98},
#     {'sle': 4.9, 'swi': 2.5, 'ple': 4.5, 'pwi': 1.7, 'class': 2.0, 'id': 106},
#     {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0, 'id': 108},
#     {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0, 'id': 113},
#     {'sle': 6.3,
#      'swi': 2.5,
#      'ple': 5.0,
#      'pwi': 1.9,
#      'class': 2.0,
#      'id': 146}]},
#   {'value': 2.6,
#    'samples': [{'sle': 5.7,
#      'swi': 2.6,
#      'ple': 3.5,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 79},
#     {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0, 'id': 90},
#     {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0, 'id': 92},
#     {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0, 'id': 118},
#     {'sle': 6.1,
#      'swi': 2.6,
#      'ple': 5.6,
#      'pwi': 1.4,
#      'class': 2.0,
#      'id': 134}]},
#   {'value': 2.7,
#    'samples': [{'sle': 5.2,
#      'swi': 2.7,
#      'ple': 3.9,
#      'pwi': 1.4,
#      'class': 1.0,
#      'id': 59},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0, 'id': 67},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0, 'id': 82},
#     {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0, 'id': 83},
#     {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0, 'id': 94},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0, 'id': 101},
#     {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0, 'id': 111},
#     {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0, 'id': 123},
#     {'sle': 5.8,
#      'swi': 2.7,
#      'ple': 5.1,
#      'pwi': 1.9,
#      'class': 2.0,
#      'id': 142}]},
#   {'value': 2.8,
#    'samples': [{'sle': 6.5,
#      'swi': 2.8,
#      'ple': 4.6,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 54},
#     {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0, 'id': 55},
#     {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 71},
#     {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0, 'id': 73},
#     {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0, 'id': 76},
#     {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0, 'id': 99},
#     {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0, 'id': 114},
#     {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0, 'id': 121},
#     {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0, 'id': 122},
#     {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0, 'id': 126},
#     {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0, 'id': 128},
#     {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0, 'id': 130},
#     {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0, 'id': 132},
#     {'sle': 6.3,
#      'swi': 2.8,
#      'ple': 5.1,
#      'pwi': 1.5,
#      'class': 2.0,
#      'id': 133}]},
#   {'value': 2.9,
#    'samples': [{'sle': 4.4,
#      'swi': 2.9,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 8},
#     {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0, 'id': 58},
#     {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0, 'id': 63},
#     {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0, 'id': 64},
#     {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0, 'id': 74},
#     {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 78},
#     {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0, 'id': 96},
#     {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0, 'id': 97},
#     {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0, 'id': 103},
#     {'sle': 7.3,
#      'swi': 2.9,
#      'ple': 6.3,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 107}]},
#   {'value': 3.0,
#    'samples': [{'sle': 4.9,
#      'swi': 3.0,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 1},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 12},
#     {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0, 'id': 13},
#     {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 25},
#     {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 38},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 45},
#     {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0, 'id': 61},
#     {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 66},
#     {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0, 'id': 75},
#     {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0, 'id': 77},
#     {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 84},
#     {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0, 'id': 88},
#     {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0, 'id': 91},
#     {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0, 'id': 95},
#     {'sle': 7.1, 'swi': 3.0, 'ple': 5.9, 'pwi': 2.1, 'class': 2.0, 'id': 102},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0, 'id': 104},
#     {'sle': 7.6, 'swi': 3.0, 'ple': 6.6, 'pwi': 2.1, 'class': 2.0, 'id': 105},
#     {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0, 'id': 112},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0, 'id': 116},
#     {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0, 'id': 127},
#     {'sle': 7.2, 'swi': 3.0, 'ple': 5.8, 'pwi': 1.6, 'class': 2.0, 'id': 129},
#     {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0, 'id': 135},
#     {'sle': 6.0, 'swi': 3.0, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0, 'id': 138},
#     {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0, 'id': 145},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.0, 'class': 2.0, 'id': 147},
#     {'sle': 5.9,
#      'swi': 3.0,
#      'ple': 5.1,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 149}]},
#   {'value': 3.1,
#    'samples': [{'sle': 4.6,
#      'swi': 3.1,
#      'ple': 1.5,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 3},
#     {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0, 'id': 9},
#     {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 30},
#     {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 34},
#     {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0, 'id': 52},
#     {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0, 'id': 65},
#     {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0, 'id': 86},
#     {'sle': 6.4, 'swi': 3.1, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0, 'id': 137},
#     {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0, 'id': 139},
#     {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0, 'id': 140},
#     {'sle': 6.9,
#      'swi': 3.1,
#      'ple': 5.1,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 141}]},
#   {'value': 3.2,
#    'samples': [{'sle': 4.7,
#      'swi': 3.2,
#      'ple': 1.3,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 2},
#     {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 29},
#     {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0, 'id': 35},
#     {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 42},
#     {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 47},
#     {'sle': 7.0, 'swi': 3.2, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0, 'id': 50},
#     {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 51},
#     {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0, 'id': 70},
#     {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0, 'id': 110},
#     {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0, 'id': 115},
#     {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0, 'id': 120},
#     {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0, 'id': 125},
#     {'sle': 6.8,
#      'swi': 3.2,
#      'ple': 5.9,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 143}]},
#   {'value': 3.3,
#    'samples': [{'sle': 5.1,
#      'swi': 3.3,
#      'ple': 1.7,
#      'pwi': 0.5,
#      'class': 0.0,
#      'id': 23},
#     {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 49},
#     {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0, 'id': 56},
#     {'sle': 6.3, 'swi': 3.3, 'ple': 6.0, 'pwi': 2.5, 'class': 2.0, 'id': 100},
#     {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0, 'id': 124},
#     {'sle': 6.7,
#      'swi': 3.3,
#      'ple': 5.7,
#      'pwi': 2.5,
#      'class': 2.0,
#      'id': 144}]},
#   {'value': 3.4,
#    'samples': [{'sle': 4.6,
#      'swi': 3.4,
#      'ple': 1.4,
#      'pwi': 0.3,
#      'class': 0.0,
#      'id': 6},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 7},
#     {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 11},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0, 'id': 20},
#     {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0, 'id': 24},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0, 'id': 26},
#     {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 28},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 31},
#     {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 39},
#     {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0, 'id': 85},
#     {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0, 'id': 136},
#     {'sle': 6.2,
#      'swi': 3.4,
#      'ple': 5.4,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 148}]},
#   {'value': 3.5,
#    'samples': [{'sle': 5.1,
#      'swi': 3.5,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 0},
#     {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 17},
#     {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 27},
#     {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 36},
#     {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0, 'id': 40},
#     {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0, 'id': 43}]},
#   {'value': 3.6,
#    'samples': [{'sle': 5.0,
#      'swi': 3.6,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 4},
#     {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0, 'id': 22},
#     {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 37},
#     {'sle': 7.2,
#      'swi': 3.6,
#      'ple': 6.1,
#      'pwi': 2.5,
#      'class': 2.0,
#      'id': 109}]},
#   {'value': 3.7,
#    'samples': [{'sle': 5.4,
#      'swi': 3.7,
#      'ple': 1.5,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 10},
#     {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 21},
#     {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 48}]},
#   {'value': 3.8,
#    'samples': [{'sle': 5.7,
#      'swi': 3.8,
#      'ple': 1.7,
#      'pwi': 0.3,
#      'class': 0.0,
#      'id': 18},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0, 'id': 19},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0, 'id': 44},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 46},
#     {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0, 'id': 117},
#     {'sle': 7.9,
#      'swi': 3.8,
#      'ple': 6.4,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 131}]},
#   {'value': 3.9,
#    'samples': [{'sle': 5.4,
#      'swi': 3.9,
#      'ple': 1.7,
#      'pwi': 0.4,
#      'class': 0.0,
#      'id': 5},
#     {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0, 'id': 16}]},
#   {'value': 4.0,
#    'samples': [{'sle': 5.8,
#      'swi': 4.0,
#      'ple': 1.2,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 14}]},
#   {'value': 4.1,
#    'samples': [{'sle': 5.2,
#      'swi': 4.1,
#      'ple': 1.5,
#      'pwi': 0.1,
#      'class': 0.0,
#      'id': 32}]},
#   {'value': 4.2,
#    'samples': [{'sle': 5.5,
#      'swi': 4.2,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 33}]},
#   {'value': 4.4,
#    'samples': [{'sle': 5.7,
#      'swi': 4.4,
#      'ple': 1.5,
#      'pwi': 0.4,
#      'class': 0.0,
#      'id': 15}]}],
#  'ple': [{'value': 1.0,
#    'samples': [{'sle': 4.6,
#      'swi': 3.6,
#      'ple': 1.0,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 22}]},
#   {'value': 1.1,
#    'samples': [{'sle': 4.3,
#      'swi': 3.0,
#      'ple': 1.1,
#      'pwi': 0.1,
#      'class': 0.0,
#      'id': 13}]},
#   {'value': 1.2,
#    'samples': [{'sle': 5.8,
#      'swi': 4.0,
#      'ple': 1.2,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 14},
#     {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0, 'id': 35}]},
#   {'value': 1.3,
#    'samples': [{'sle': 4.7,
#      'swi': 3.2,
#      'ple': 1.3,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 2},
#     {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0, 'id': 16},
#     {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 36},
#     {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 38},
#     {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0, 'id': 40},
#     {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0, 'id': 41},
#     {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 42}]},
#   {'value': 1.4,
#    'samples': [{'sle': 5.1,
#      'swi': 3.5,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 0},
#     {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 1},
#     {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 4},
#     {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 6},
#     {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 8},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 12},
#     {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 17},
#     {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 28},
#     {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 33},
#     {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 37},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 45},
#     {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 47},
#     {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 49}]},
#   {'value': 1.5,
#    'samples': [{'sle': 4.6,
#      'swi': 3.1,
#      'ple': 1.5,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 3},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 7},
#     {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0, 'id': 9},
#     {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 10},
#     {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 15},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0, 'id': 19},
#     {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 21},
#     {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 27},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 31},
#     {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0, 'id': 32},
#     {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 34},
#     {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 39},
#     {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 48}]},
#   {'value': 1.6,
#    'samples': [{'sle': 4.8,
#      'swi': 3.4,
#      'ple': 1.6,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 11},
#     {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 25},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0, 'id': 26},
#     {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 29},
#     {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 30},
#     {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0, 'id': 43},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 46}]},
#   {'value': 1.7,
#    'samples': [{'sle': 5.4,
#      'swi': 3.9,
#      'ple': 1.7,
#      'pwi': 0.4,
#      'class': 0.0,
#      'id': 5},
#     {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0, 'id': 18},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0, 'id': 20},
#     {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0, 'id': 23}]},
#   {'value': 1.9,
#    'samples': [{'sle': 4.8,
#      'swi': 3.4,
#      'ple': 1.9,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 24},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0, 'id': 44}]},
#   {'value': 3.0,
#    'samples': [{'sle': 5.1,
#      'swi': 2.5,
#      'ple': 3.0,
#      'pwi': 1.1,
#      'class': 1.0,
#      'id': 98}]},
#   {'value': 3.3,
#    'samples': [{'sle': 4.9,
#      'swi': 2.4,
#      'ple': 3.3,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 57},
#     {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0, 'id': 93}]},
#   {'value': 3.5,
#    'samples': [{'sle': 5.0,
#      'swi': 2.0,
#      'ple': 3.5,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 60},
#     {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0, 'id': 79}]},
#   {'value': 3.6,
#    'samples': [{'sle': 5.6,
#      'swi': 2.9,
#      'ple': 3.6,
#      'pwi': 1.3,
#      'class': 1.0,
#      'id': 64}]},
#   {'value': 3.7,
#    'samples': [{'sle': 5.5,
#      'swi': 2.4,
#      'ple': 3.7,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 81}]},
#   {'value': 3.8,
#    'samples': [{'sle': 5.5,
#      'swi': 2.4,
#      'ple': 3.8,
#      'pwi': 1.1,
#      'class': 1.0,
#      'id': 80}]},
#   {'value': 3.9,
#    'samples': [{'sle': 5.2,
#      'swi': 2.7,
#      'ple': 3.9,
#      'pwi': 1.4,
#      'class': 1.0,
#      'id': 59},
#     {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0, 'id': 69},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0, 'id': 82}]},
#   {'value': 4.0,
#    'samples': [{'sle': 5.5,
#      'swi': 2.3,
#      'ple': 4.0,
#      'pwi': 1.3,
#      'class': 1.0,
#      'id': 53},
#     {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0, 'id': 62},
#     {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 71},
#     {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 89},
#     {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0, 'id': 92}]},
#   {'value': 4.1,
#    'samples': [{'sle': 5.8,
#      'swi': 2.7,
#      'ple': 4.1,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 67},
#     {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0, 'id': 88},
#     {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0, 'id': 99}]},
#   {'value': 4.2,
#    'samples': [{'sle': 5.9,
#      'swi': 3.0,
#      'ple': 4.2,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 61},
#     {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0, 'id': 94},
#     {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0, 'id': 95},
#     {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0, 'id': 96}]},
#   {'value': 4.3,
#    'samples': [{'sle': 6.4,
#      'swi': 2.9,
#      'ple': 4.3,
#      'pwi': 1.3,
#      'class': 1.0,
#      'id': 74},
#     {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0, 'id': 97}]},
#   {'value': 4.4,
#    'samples': [{'sle': 6.7,
#      'swi': 3.1,
#      'ple': 4.4,
#      'pwi': 1.4,
#      'class': 1.0,
#      'id': 65},
#     {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0, 'id': 75},
#     {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0, 'id': 87},
#     {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0, 'id': 90}]},
#   {'value': 4.5,
#    'samples': [{'sle': 6.4,
#      'swi': 3.2,
#      'ple': 4.5,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 51},
#     {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0, 'id': 55},
#     {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 66},
#     {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 68},
#     {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 78},
#     {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 84},
#     {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0, 'id': 85},
#     {'sle': 4.9,
#      'swi': 2.5,
#      'ple': 4.5,
#      'pwi': 1.7,
#      'class': 2.0,
#      'id': 106}]},
#   {'value': 4.6,
#    'samples': [{'sle': 6.5,
#      'swi': 2.8,
#      'ple': 4.6,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 54},
#     {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0, 'id': 58},
#     {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0, 'id': 91}]},
#   {'value': 4.7,
#    'samples': [{'sle': 7.0,
#      'swi': 3.2,
#      'ple': 4.7,
#      'pwi': 1.4,
#      'class': 1.0,
#      'id': 50},
#     {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0, 'id': 56},
#     {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0, 'id': 63},
#     {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0, 'id': 73},
#     {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0, 'id': 86}]},
#   {'value': 4.8,
#    'samples': [{'sle': 5.9,
#      'swi': 3.2,
#      'ple': 4.8,
#      'pwi': 1.8,
#      'class': 1.0,
#      'id': 70},
#     {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0, 'id': 76},
#     {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0, 'id': 126},
#     {'sle': 6.0,
#      'swi': 3.0,
#      'ple': 4.8,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 138}]},
#   {'value': 4.9,
#    'samples': [{'sle': 6.9,
#      'swi': 3.1,
#      'ple': 4.9,
#      'pwi': 1.5,
#      'class': 1.0,
#      'id': 52},
#     {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0, 'id': 72},
#     {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0, 'id': 121},
#     {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0, 'id': 123},
#     {'sle': 6.1,
#      'swi': 3.0,
#      'ple': 4.9,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 127}]},
#   {'value': 5.0,
#    'samples': [{'sle': 6.7,
#      'swi': 3.0,
#      'ple': 5.0,
#      'pwi': 1.7,
#      'class': 1.0,
#      'id': 77},
#     {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0, 'id': 113},
#     {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0, 'id': 119},
#     {'sle': 6.3,
#      'swi': 2.5,
#      'ple': 5.0,
#      'pwi': 1.9,
#      'class': 2.0,
#      'id': 146}]},
#   {'value': 5.1,
#    'samples': [{'sle': 6.0,
#      'swi': 2.7,
#      'ple': 5.1,
#      'pwi': 1.6,
#      'class': 1.0,
#      'id': 83},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0, 'id': 101},
#     {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0, 'id': 110},
#     {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0, 'id': 114},
#     {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0, 'id': 133},
#     {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0, 'id': 141},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0, 'id': 142},
#     {'sle': 5.9,
#      'swi': 3.0,
#      'ple': 5.1,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 149}]},
#   {'value': 5.2,
#    'samples': [{'sle': 6.7,
#      'swi': 3.0,
#      'ple': 5.2,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 145},
#     {'sle': 6.5,
#      'swi': 3.0,
#      'ple': 5.2,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 147}]},
#   {'value': 5.3,
#    'samples': [{'sle': 6.4,
#      'swi': 2.7,
#      'ple': 5.3,
#      'pwi': 1.9,
#      'class': 2.0,
#      'id': 111},
#     {'sle': 6.4,
#      'swi': 3.2,
#      'ple': 5.3,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 115}]},
#   {'value': 5.4,
#    'samples': [{'sle': 6.9,
#      'swi': 3.1,
#      'ple': 5.4,
#      'pwi': 2.1,
#      'class': 2.0,
#      'id': 139},
#     {'sle': 6.2,
#      'swi': 3.4,
#      'ple': 5.4,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 148}]},
#   {'value': 5.5,
#    'samples': [{'sle': 6.8,
#      'swi': 3.0,
#      'ple': 5.5,
#      'pwi': 2.1,
#      'class': 2.0,
#      'id': 112},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0, 'id': 116},
#     {'sle': 6.4,
#      'swi': 3.1,
#      'ple': 5.5,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 137}]},
#   {'value': 5.6,
#    'samples': [{'sle': 6.3,
#      'swi': 2.9,
#      'ple': 5.6,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 103},
#     {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0, 'id': 128},
#     {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0, 'id': 132},
#     {'sle': 6.1, 'swi': 2.6, 'ple': 5.6, 'pwi': 1.4, 'class': 2.0, 'id': 134},
#     {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0, 'id': 136},
#     {'sle': 6.7,
#      'swi': 3.1,
#      'ple': 5.6,
#      'pwi': 2.4,
#      'class': 2.0,
#      'id': 140}]},
#   {'value': 5.7,
#    'samples': [{'sle': 6.9,
#      'swi': 3.2,
#      'ple': 5.7,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 120},
#     {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0, 'id': 124},
#     {'sle': 6.7,
#      'swi': 3.3,
#      'ple': 5.7,
#      'pwi': 2.5,
#      'class': 2.0,
#      'id': 144}]},
#   {'value': 5.8,
#    'samples': [{'sle': 6.5,
#      'swi': 3.0,
#      'ple': 5.8,
#      'pwi': 2.2,
#      'class': 2.0,
#      'id': 104},
#     {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0, 'id': 108},
#     {'sle': 7.2,
#      'swi': 3.0,
#      'ple': 5.8,
#      'pwi': 1.6,
#      'class': 2.0,
#      'id': 129}]},
#   {'value': 5.9,
#    'samples': [{'sle': 7.1,
#      'swi': 3.0,
#      'ple': 5.9,
#      'pwi': 2.1,
#      'class': 2.0,
#      'id': 102},
#     {'sle': 6.8,
#      'swi': 3.2,
#      'ple': 5.9,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 143}]},
#   {'value': 6.0,
#    'samples': [{'sle': 6.3,
#      'swi': 3.3,
#      'ple': 6.0,
#      'pwi': 2.5,
#      'class': 2.0,
#      'id': 100},
#     {'sle': 7.2,
#      'swi': 3.2,
#      'ple': 6.0,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 125}]},
#   {'value': 6.1,
#    'samples': [{'sle': 7.2,
#      'swi': 3.6,
#      'ple': 6.1,
#      'pwi': 2.5,
#      'class': 2.0,
#      'id': 109},
#     {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0, 'id': 130},
#     {'sle': 7.7,
#      'swi': 3.0,
#      'ple': 6.1,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 135}]},
#   {'value': 6.3,
#    'samples': [{'sle': 7.3,
#      'swi': 2.9,
#      'ple': 6.3,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 107}]},
#   {'value': 6.4,
#    'samples': [{'sle': 7.9,
#      'swi': 3.8,
#      'ple': 6.4,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 131}]},
#   {'value': 6.6,
#    'samples': [{'sle': 7.6,
#      'swi': 3.0,
#      'ple': 6.6,
#      'pwi': 2.1,
#      'class': 2.0,
#      'id': 105}]},
#   {'value': 6.7,
#    'samples': [{'sle': 7.7,
#      'swi': 3.8,
#      'ple': 6.7,
#      'pwi': 2.2,
#      'class': 2.0,
#      'id': 117},
#     {'sle': 7.7,
#      'swi': 2.8,
#      'ple': 6.7,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 122}]},
#   {'value': 6.9,
#    'samples': [{'sle': 7.7,
#      'swi': 2.6,
#      'ple': 6.9,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 118}]}],
#  'pwi': [{'value': 0.1,
#    'samples': [{'sle': 4.9,
#      'swi': 3.1,
#      'ple': 1.5,
#      'pwi': 0.1,
#      'class': 0.0,
#      'id': 9},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 12},
#     {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0, 'id': 13},
#     {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0, 'id': 32},
#     {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 37}]},
#   {'value': 0.2,
#    'samples': [{'sle': 5.1,
#      'swi': 3.5,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 0},
#     {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 1},
#     {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 2},
#     {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 3},
#     {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 4},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 7},
#     {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 8},
#     {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 10},
#     {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 11},
#     {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0, 'id': 14},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0, 'id': 20},
#     {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0, 'id': 22},
#     {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0, 'id': 24},
#     {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 25},
#     {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 27},
#     {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 28},
#     {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 29},
#     {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 30},
#     {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 33},
#     {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 34},
#     {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0, 'id': 35},
#     {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 36},
#     {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 38},
#     {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 39},
#     {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 42},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 46},
#     {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 47},
#     {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 48},
#     {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 49}]},
#   {'value': 0.3,
#    'samples': [{'sle': 4.6,
#      'swi': 3.4,
#      'ple': 1.4,
#      'pwi': 0.3,
#      'class': 0.0,
#      'id': 6},
#     {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 17},
#     {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0, 'id': 18},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0, 'id': 19},
#     {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0, 'id': 40},
#     {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0, 'id': 41},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 45}]},
#   {'value': 0.4,
#    'samples': [{'sle': 5.4,
#      'swi': 3.9,
#      'ple': 1.7,
#      'pwi': 0.4,
#      'class': 0.0,
#      'id': 5},
#     {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 15},
#     {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0, 'id': 16},
#     {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 21},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0, 'id': 26},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 31},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0, 'id': 44}]},
#   {'value': 0.5,
#    'samples': [{'sle': 5.1,
#      'swi': 3.3,
#      'ple': 1.7,
#      'pwi': 0.5,
#      'class': 0.0,
#      'id': 23}]},
#   {'value': 0.6,
#    'samples': [{'sle': 5.0,
#      'swi': 3.5,
#      'ple': 1.6,
#      'pwi': 0.6,
#      'class': 0.0,
#      'id': 43}]},
#   {'value': 1.0,
#    'samples': [{'sle': 4.9,
#      'swi': 2.4,
#      'ple': 3.3,
#      'pwi': 1.0,
#      'class': 1.0,
#      'id': 57},
#     {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0, 'id': 60},
#     {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0, 'id': 62},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0, 'id': 67},
#     {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0, 'id': 79},
#     {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0, 'id': 81},
#     {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0, 'id': 93}]},
#   {'value': 1.1,
#    'samples': [{'sle': 5.6,
#      'swi': 2.5,
#      'ple': 3.9,
#      'pwi': 1.1,
#      'class': 1.0,
#      'id': 69},
#     {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0, 'id': 80},
#     {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0, 'id': 98}]},
#   {'value': 1.2,
#    'samples': [{'sle': 6.1,
#      'swi': 2.8,
#      'ple': 4.7,
#      'pwi': 1.2,
#      'class': 1.0,
#      'id': 73},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0, 'id': 82},
#     {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0, 'id': 90},
#     {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0, 'id': 92},
#     {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0, 'id': 95}]},
#   {'value': 1.3,
#    'samples': [{'sle': 5.5,
#      'swi': 2.3,
#      'ple': 4.0,
#      'pwi': 1.3,
#      'class': 1.0,
#      'id': 53},
#     {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0, 'id': 55},
#     {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0, 'id': 58},
#     {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0, 'id': 64},
#     {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 71},
# ...
#     {'sle': 7.3, 'swi': 2.9, 'ple': 6.3, 'pwi': 1.8, 'class': 2.0, 'id': 107},
#     {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0, 'id': 108},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0, 'id': 116},
#     {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0, 'id': 123},
#     {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0, 'id': 125},
#     {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0, 'id': 126},
#     {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0, 'id': 127},
#     {'sle': 6.4, 'swi': 3.1, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0, 'id': 137},
#     {'sle': 6.0, 'swi': 3.0, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0, 'id': 138},
#     {'sle': 5.9,
#      'swi': 3.0,
#      'ple': 5.1,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 149}]},
#   {'value': 1.9,
#    'samples': [{'sle': 5.8,
#      'swi': 2.7,
#      'ple': 5.1,
#      'pwi': 1.9,
#      'class': 2.0,
#      'id': 101},
#     {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0, 'id': 111},
#     {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0, 'id': 130},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0, 'id': 142},
#     {'sle': 6.3,
#      'swi': 2.5,
#      'ple': 5.0,
#      'pwi': 1.9,
#      'class': 2.0,
#      'id': 146}]},
#   {'value': 2.0,
#    'samples': [{'sle': 6.5,
#      'swi': 3.2,
#      'ple': 5.1,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 110},
#     {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0, 'id': 113},
#     {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0, 'id': 121},
#     {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0, 'id': 122},
#     {'sle': 7.9, 'swi': 3.8, 'ple': 6.4, 'pwi': 2.0, 'class': 2.0, 'id': 131},
#     {'sle': 6.5,
#      'swi': 3.0,
#      'ple': 5.2,
#      'pwi': 2.0,
#      'class': 2.0,
#      'id': 147}]},
#   {'value': 2.1,
#    'samples': [{'sle': 7.1,
#      'swi': 3.0,
#      'ple': 5.9,
#      'pwi': 2.1,
#      'class': 2.0,
#      'id': 102},
#     {'sle': 7.6, 'swi': 3.0, 'ple': 6.6, 'pwi': 2.1, 'class': 2.0, 'id': 105},
#     {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0, 'id': 112},
#     {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0, 'id': 124},
#     {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0, 'id': 128},
#     {'sle': 6.9,
#      'swi': 3.1,
#      'ple': 5.4,
#      'pwi': 2.1,
#      'class': 2.0,
#      'id': 139}]},
#   {'value': 2.2,
#    'samples': [{'sle': 6.5,
#      'swi': 3.0,
#      'ple': 5.8,
#      'pwi': 2.2,
#      'class': 2.0,
#      'id': 104},
#     {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0, 'id': 117},
#     {'sle': 6.4,
#      'swi': 2.8,
#      'ple': 5.6,
#      'pwi': 2.2,
#      'class': 2.0,
#      'id': 132}]},
#   {'value': 2.3,
#    'samples': [{'sle': 6.4,
#      'swi': 3.2,
#      'ple': 5.3,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 115},
#     {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0, 'id': 118},
#     {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0, 'id': 120},
#     {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0, 'id': 135},
#     {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0, 'id': 141},
#     {'sle': 6.8, 'swi': 3.2, 'ple': 5.9, 'pwi': 2.3, 'class': 2.0, 'id': 143},
#     {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0, 'id': 145},
#     {'sle': 6.2,
#      'swi': 3.4,
#      'ple': 5.4,
#      'pwi': 2.3,
#      'class': 2.0,
#      'id': 148}]},
#   {'value': 2.4,
#    'samples': [{'sle': 5.8,
#      'swi': 2.8,
#      'ple': 5.1,
#      'pwi': 2.4,
#      'class': 2.0,
#      'id': 114},
#     {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0, 'id': 136},
#     {'sle': 6.7,
#      'swi': 3.1,
#      'ple': 5.6,
#      'pwi': 2.4,
#      'class': 2.0,
#      'id': 140}]},
#   {'value': 2.5,
#    'samples': [{'sle': 6.3,
#      'swi': 3.3,
#      'ple': 6.0,
#      'pwi': 2.5,
#      'class': 2.0,
#      'id': 100},
#     {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0, 'id': 109},
#     {'sle': 6.7,
#      'swi': 3.3,
#      'ple': 5.7,
#      'pwi': 2.5,
#      'class': 2.0,
#      'id': 144}]}],
#  'class': [{'value': 0,
#    'samples': [{'sle': 5.1,
#      'swi': 3.5,
#      'ple': 1.4,
#      'pwi': 0.2,
#      'class': 0.0,
#      'id': 0},
#     {'sle': 4.9, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 1},
#     {'sle': 4.7, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 2},
#     {'sle': 4.6, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 3},
#     {'sle': 5.0, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 4},
#     {'sle': 5.4, 'swi': 3.9, 'ple': 1.7, 'pwi': 0.4, 'class': 0.0, 'id': 5},
#     {'sle': 4.6, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 6},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 7},
#     {'sle': 4.4, 'swi': 2.9, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 8},
#     {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0, 'id': 9},
#     {'sle': 5.4, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 10},
#     {'sle': 4.8, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 11},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 12},
#     {'sle': 4.3, 'swi': 3.0, 'ple': 1.1, 'pwi': 0.1, 'class': 0.0, 'id': 13},
#     {'sle': 5.8, 'swi': 4.0, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0, 'id': 14},
#     {'sle': 5.7, 'swi': 4.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 15},
#     {'sle': 5.4, 'swi': 3.9, 'ple': 1.3, 'pwi': 0.4, 'class': 0.0, 'id': 16},
#     {'sle': 5.1, 'swi': 3.5, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 17},
#     {'sle': 5.7, 'swi': 3.8, 'ple': 1.7, 'pwi': 0.3, 'class': 0.0, 'id': 18},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.5, 'pwi': 0.3, 'class': 0.0, 'id': 19},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.7, 'pwi': 0.2, 'class': 0.0, 'id': 20},
#     {'sle': 5.1, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 21},
#     {'sle': 4.6, 'swi': 3.6, 'ple': 1.0, 'pwi': 0.2, 'class': 0.0, 'id': 22},
#     {'sle': 5.1, 'swi': 3.3, 'ple': 1.7, 'pwi': 0.5, 'class': 0.0, 'id': 23},
#     {'sle': 4.8, 'swi': 3.4, 'ple': 1.9, 'pwi': 0.2, 'class': 0.0, 'id': 24},
#     {'sle': 5.0, 'swi': 3.0, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 25},
#     {'sle': 5.0, 'swi': 3.4, 'ple': 1.6, 'pwi': 0.4, 'class': 0.0, 'id': 26},
#     {'sle': 5.2, 'swi': 3.5, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 27},
#     {'sle': 5.2, 'swi': 3.4, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 28},
#     {'sle': 4.7, 'swi': 3.2, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 29},
#     {'sle': 4.8, 'swi': 3.1, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 30},
#     {'sle': 5.4, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.4, 'class': 0.0, 'id': 31},
#     {'sle': 5.2, 'swi': 4.1, 'ple': 1.5, 'pwi': 0.1, 'class': 0.0, 'id': 32},
#     {'sle': 5.5, 'swi': 4.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 33},
#     {'sle': 4.9, 'swi': 3.1, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 34},
#     {'sle': 5.0, 'swi': 3.2, 'ple': 1.2, 'pwi': 0.2, 'class': 0.0, 'id': 35},
#     {'sle': 5.5, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 36},
#     {'sle': 4.9, 'swi': 3.6, 'ple': 1.4, 'pwi': 0.1, 'class': 0.0, 'id': 37},
#     {'sle': 4.4, 'swi': 3.0, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 38},
#     {'sle': 5.1, 'swi': 3.4, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 39},
#     {'sle': 5.0, 'swi': 3.5, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0, 'id': 40},
#     {'sle': 4.5, 'swi': 2.3, 'ple': 1.3, 'pwi': 0.3, 'class': 0.0, 'id': 41},
#     {'sle': 4.4, 'swi': 3.2, 'ple': 1.3, 'pwi': 0.2, 'class': 0.0, 'id': 42},
#     {'sle': 5.0, 'swi': 3.5, 'ple': 1.6, 'pwi': 0.6, 'class': 0.0, 'id': 43},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.9, 'pwi': 0.4, 'class': 0.0, 'id': 44},
#     {'sle': 4.8, 'swi': 3.0, 'ple': 1.4, 'pwi': 0.3, 'class': 0.0, 'id': 45},
#     {'sle': 5.1, 'swi': 3.8, 'ple': 1.6, 'pwi': 0.2, 'class': 0.0, 'id': 46},
#     {'sle': 4.6, 'swi': 3.2, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 47},
#     {'sle': 5.3, 'swi': 3.7, 'ple': 1.5, 'pwi': 0.2, 'class': 0.0, 'id': 48},
#     {'sle': 5.0, 'swi': 3.3, 'ple': 1.4, 'pwi': 0.2, 'class': 0.0, 'id': 49}]},
#   {'value': 1,
#    'samples': [{'sle': 7.0,
#      'swi': 3.2,
#      'ple': 4.7,
#      'pwi': 1.4,
#      'class': 1.0,
#      'id': 50},
#     {'sle': 6.4, 'swi': 3.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 51},
#     {'sle': 6.9, 'swi': 3.1, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0, 'id': 52},
#     {'sle': 5.5, 'swi': 2.3, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 53},
#     {'sle': 6.5, 'swi': 2.8, 'ple': 4.6, 'pwi': 1.5, 'class': 1.0, 'id': 54},
#     {'sle': 5.7, 'swi': 2.8, 'ple': 4.5, 'pwi': 1.3, 'class': 1.0, 'id': 55},
#     {'sle': 6.3, 'swi': 3.3, 'ple': 4.7, 'pwi': 1.6, 'class': 1.0, 'id': 56},
#     {'sle': 4.9, 'swi': 2.4, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0, 'id': 57},
#     {'sle': 6.6, 'swi': 2.9, 'ple': 4.6, 'pwi': 1.3, 'class': 1.0, 'id': 58},
#     {'sle': 5.2, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.4, 'class': 1.0, 'id': 59},
#     {'sle': 5.0, 'swi': 2.0, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0, 'id': 60},
#     {'sle': 5.9, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.5, 'class': 1.0, 'id': 61},
#     {'sle': 6.0, 'swi': 2.2, 'ple': 4.0, 'pwi': 1.0, 'class': 1.0, 'id': 62},
#     {'sle': 6.1, 'swi': 2.9, 'ple': 4.7, 'pwi': 1.4, 'class': 1.0, 'id': 63},
#     {'sle': 5.6, 'swi': 2.9, 'ple': 3.6, 'pwi': 1.3, 'class': 1.0, 'id': 64},
#     {'sle': 6.7, 'swi': 3.1, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0, 'id': 65},
#     {'sle': 5.6, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 66},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 4.1, 'pwi': 1.0, 'class': 1.0, 'id': 67},
#     {'sle': 6.2, 'swi': 2.2, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 68},
#     {'sle': 5.6, 'swi': 2.5, 'ple': 3.9, 'pwi': 1.1, 'class': 1.0, 'id': 69},
#     {'sle': 5.9, 'swi': 3.2, 'ple': 4.8, 'pwi': 1.8, 'class': 1.0, 'id': 70},
#     {'sle': 6.1, 'swi': 2.8, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 71},
#     {'sle': 6.3, 'swi': 2.5, 'ple': 4.9, 'pwi': 1.5, 'class': 1.0, 'id': 72},
#     {'sle': 6.1, 'swi': 2.8, 'ple': 4.7, 'pwi': 1.2, 'class': 1.0, 'id': 73},
#     {'sle': 6.4, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0, 'id': 74},
#     {'sle': 6.6, 'swi': 3.0, 'ple': 4.4, 'pwi': 1.4, 'class': 1.0, 'id': 75},
#     {'sle': 6.8, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.4, 'class': 1.0, 'id': 76},
#     {'sle': 6.7, 'swi': 3.0, 'ple': 5.0, 'pwi': 1.7, 'class': 1.0, 'id': 77},
#     {'sle': 6.0, 'swi': 2.9, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 78},
#     {'sle': 5.7, 'swi': 2.6, 'ple': 3.5, 'pwi': 1.0, 'class': 1.0, 'id': 79},
#     {'sle': 5.5, 'swi': 2.4, 'ple': 3.8, 'pwi': 1.1, 'class': 1.0, 'id': 80},
#     {'sle': 5.5, 'swi': 2.4, 'ple': 3.7, 'pwi': 1.0, 'class': 1.0, 'id': 81},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 3.9, 'pwi': 1.2, 'class': 1.0, 'id': 82},
#     {'sle': 6.0, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.6, 'class': 1.0, 'id': 83},
#     {'sle': 5.4, 'swi': 3.0, 'ple': 4.5, 'pwi': 1.5, 'class': 1.0, 'id': 84},
#     {'sle': 6.0, 'swi': 3.4, 'ple': 4.5, 'pwi': 1.6, 'class': 1.0, 'id': 85},
#     {'sle': 6.7, 'swi': 3.1, 'ple': 4.7, 'pwi': 1.5, 'class': 1.0, 'id': 86},
#     {'sle': 6.3, 'swi': 2.3, 'ple': 4.4, 'pwi': 1.3, 'class': 1.0, 'id': 87},
#     {'sle': 5.6, 'swi': 3.0, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0, 'id': 88},
#     {'sle': 5.5, 'swi': 2.5, 'ple': 4.0, 'pwi': 1.3, 'class': 1.0, 'id': 89},
#     {'sle': 5.5, 'swi': 2.6, 'ple': 4.4, 'pwi': 1.2, 'class': 1.0, 'id': 90},
#     {'sle': 6.1, 'swi': 3.0, 'ple': 4.6, 'pwi': 1.4, 'class': 1.0, 'id': 91},
#     {'sle': 5.8, 'swi': 2.6, 'ple': 4.0, 'pwi': 1.2, 'class': 1.0, 'id': 92},
#     {'sle': 5.0, 'swi': 2.3, 'ple': 3.3, 'pwi': 1.0, 'class': 1.0, 'id': 93},
#     {'sle': 5.6, 'swi': 2.7, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0, 'id': 94},
#     {'sle': 5.7, 'swi': 3.0, 'ple': 4.2, 'pwi': 1.2, 'class': 1.0, 'id': 95},
#     {'sle': 5.7, 'swi': 2.9, 'ple': 4.2, 'pwi': 1.3, 'class': 1.0, 'id': 96},
#     {'sle': 6.2, 'swi': 2.9, 'ple': 4.3, 'pwi': 1.3, 'class': 1.0, 'id': 97},
#     {'sle': 5.1, 'swi': 2.5, 'ple': 3.0, 'pwi': 1.1, 'class': 1.0, 'id': 98},
#     {'sle': 5.7, 'swi': 2.8, 'ple': 4.1, 'pwi': 1.3, 'class': 1.0, 'id': 99}]},
#   {'value': 2,
#    'samples': [{'sle': 6.3,
#      'swi': 3.3,
#      'ple': 6.0,
#      'pwi': 2.5,
#      'class': 2.0,
#      'id': 100},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0, 'id': 101},
#     {'sle': 7.1, 'swi': 3.0, 'ple': 5.9, 'pwi': 2.1, 'class': 2.0, 'id': 102},
#     {'sle': 6.3, 'swi': 2.9, 'ple': 5.6, 'pwi': 1.8, 'class': 2.0, 'id': 103},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.8, 'pwi': 2.2, 'class': 2.0, 'id': 104},
#     {'sle': 7.6, 'swi': 3.0, 'ple': 6.6, 'pwi': 2.1, 'class': 2.0, 'id': 105},
#     {'sle': 4.9, 'swi': 2.5, 'ple': 4.5, 'pwi': 1.7, 'class': 2.0, 'id': 106},
#     {'sle': 7.3, 'swi': 2.9, 'ple': 6.3, 'pwi': 1.8, 'class': 2.0, 'id': 107},
#     {'sle': 6.7, 'swi': 2.5, 'ple': 5.8, 'pwi': 1.8, 'class': 2.0, 'id': 108},
#     {'sle': 7.2, 'swi': 3.6, 'ple': 6.1, 'pwi': 2.5, 'class': 2.0, 'id': 109},
#     {'sle': 6.5, 'swi': 3.2, 'ple': 5.1, 'pwi': 2.0, 'class': 2.0, 'id': 110},
#     {'sle': 6.4, 'swi': 2.7, 'ple': 5.3, 'pwi': 1.9, 'class': 2.0, 'id': 111},
#     {'sle': 6.8, 'swi': 3.0, 'ple': 5.5, 'pwi': 2.1, 'class': 2.0, 'id': 112},
#     {'sle': 5.7, 'swi': 2.5, 'ple': 5.0, 'pwi': 2.0, 'class': 2.0, 'id': 113},
#     {'sle': 5.8, 'swi': 2.8, 'ple': 5.1, 'pwi': 2.4, 'class': 2.0, 'id': 114},
#     {'sle': 6.4, 'swi': 3.2, 'ple': 5.3, 'pwi': 2.3, 'class': 2.0, 'id': 115},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0, 'id': 116},
#     {'sle': 7.7, 'swi': 3.8, 'ple': 6.7, 'pwi': 2.2, 'class': 2.0, 'id': 117},
#     {'sle': 7.7, 'swi': 2.6, 'ple': 6.9, 'pwi': 2.3, 'class': 2.0, 'id': 118},
#     {'sle': 6.0, 'swi': 2.2, 'ple': 5.0, 'pwi': 1.5, 'class': 2.0, 'id': 119},
#     {'sle': 6.9, 'swi': 3.2, 'ple': 5.7, 'pwi': 2.3, 'class': 2.0, 'id': 120},
#     {'sle': 5.6, 'swi': 2.8, 'ple': 4.9, 'pwi': 2.0, 'class': 2.0, 'id': 121},
#     {'sle': 7.7, 'swi': 2.8, 'ple': 6.7, 'pwi': 2.0, 'class': 2.0, 'id': 122},
#     {'sle': 6.3, 'swi': 2.7, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0, 'id': 123},
#     {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.1, 'class': 2.0, 'id': 124},
#     {'sle': 7.2, 'swi': 3.2, 'ple': 6.0, 'pwi': 1.8, 'class': 2.0, 'id': 125},
#     {'sle': 6.2, 'swi': 2.8, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0, 'id': 126},
#     {'sle': 6.1, 'swi': 3.0, 'ple': 4.9, 'pwi': 1.8, 'class': 2.0, 'id': 127},
#     {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.1, 'class': 2.0, 'id': 128},
#     {'sle': 7.2, 'swi': 3.0, 'ple': 5.8, 'pwi': 1.6, 'class': 2.0, 'id': 129},
#     {'sle': 7.4, 'swi': 2.8, 'ple': 6.1, 'pwi': 1.9, 'class': 2.0, 'id': 130},
#     {'sle': 7.9, 'swi': 3.8, 'ple': 6.4, 'pwi': 2.0, 'class': 2.0, 'id': 131},
#     {'sle': 6.4, 'swi': 2.8, 'ple': 5.6, 'pwi': 2.2, 'class': 2.0, 'id': 132},
#     {'sle': 6.3, 'swi': 2.8, 'ple': 5.1, 'pwi': 1.5, 'class': 2.0, 'id': 133},
#     {'sle': 6.1, 'swi': 2.6, 'ple': 5.6, 'pwi': 1.4, 'class': 2.0, 'id': 134},
#     {'sle': 7.7, 'swi': 3.0, 'ple': 6.1, 'pwi': 2.3, 'class': 2.0, 'id': 135},
#     {'sle': 6.3, 'swi': 3.4, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0, 'id': 136},
#     {'sle': 6.4, 'swi': 3.1, 'ple': 5.5, 'pwi': 1.8, 'class': 2.0, 'id': 137},
#     {'sle': 6.0, 'swi': 3.0, 'ple': 4.8, 'pwi': 1.8, 'class': 2.0, 'id': 138},
#     {'sle': 6.9, 'swi': 3.1, 'ple': 5.4, 'pwi': 2.1, 'class': 2.0, 'id': 139},
#     {'sle': 6.7, 'swi': 3.1, 'ple': 5.6, 'pwi': 2.4, 'class': 2.0, 'id': 140},
#     {'sle': 6.9, 'swi': 3.1, 'ple': 5.1, 'pwi': 2.3, 'class': 2.0, 'id': 141},
#     {'sle': 5.8, 'swi': 2.7, 'ple': 5.1, 'pwi': 1.9, 'class': 2.0, 'id': 142},
#     {'sle': 6.8, 'swi': 3.2, 'ple': 5.9, 'pwi': 2.3, 'class': 2.0, 'id': 143},
#     {'sle': 6.7, 'swi': 3.3, 'ple': 5.7, 'pwi': 2.5, 'class': 2.0, 'id': 144},
#     {'sle': 6.7, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.3, 'class': 2.0, 'id': 145},
#     {'sle': 6.3, 'swi': 2.5, 'ple': 5.0, 'pwi': 1.9, 'class': 2.0, 'id': 146},
#     {'sle': 6.5, 'swi': 3.0, 'ple': 5.2, 'pwi': 2.0, 'class': 2.0, 'id': 147},
#     {'sle': 6.2, 'swi': 3.4, 'ple': 5.4, 'pwi': 2.3, 'class': 2.0, 'id': 148},
#     {'sle': 5.9,
#      'swi': 3.0,
#      'ple': 5.1,
#      'pwi': 1.8,
#      'class': 2.0,
#      'id': 149}]}]}
